# %% [markdown]
# # Check publication year of JSTOR articles
#
# @author: Jaren Haber, PhD, Georgetown University<br>
# @coauthors: Prof. Heather Haveman, UC Berkeley; Yoon Sung Hong, Wayfair<br>
# @contact: Jaren.Haber@georgetown.edu<br>
# @project: Computational Literature Review of Organizational Scholarship<br>
# @date: March 2021<br>
#
# @description: '''Checks publication year of articles in JSTOR Data for Research corpus. Uses original (merged) metadata as baseline; compares these with hand-checked year and year collected from Web of Science API. Goal is to validate the publication year figures in the core JSTOR metadata we are working with. From hand-checking, we've noticed many articles with incorrect values for publication year (13 incorrect out of 55 checked = 26% false positive rate).'''

# %% [markdown]
# ## Initialize

# %%
# !pip install scholarly
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.7/site-packages (3.0.5)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: tables in /opt/conda/lib/python3.7/site-packages (3.6.1)
# Requirement already satisfied: numpy>=1.9.3 in /opt/conda/lib/python3.7/site-packages (from tables) (1.19.5)
# Requirement already satisfied: numexpr>=2.6.2 in /opt/conda/lib/python3.7/site-packages (from tables) (2.6.9)
# Requirement already satisfied: fuzzywuzzy in /opt/conda/lib/python3.7/site-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in /opt/conda/lib/python3.7/site-packages (0.12.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from python-Levenshtein) (41.0.1)
# Requirement already satisfied: scholarly in /opt/conda/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.7/site-packages (from scholarly) (0.15.0)
# Requirement already satisfied: arrow in /opt/conda/lib/python3.7/site-packages (from scholarly) (0.17.0)
# Requirement already satisfied: selenium in /opt/conda/lib/python3.7/site-packages (from scholarly) (3.141.0)
# Requirement already satisfied: stem in /opt/conda/lib/python3.7/site-packages (from scholarly) (1.8.0)
# Requirement already satisfied: free-proxy in /opt/conda/lib/python3.7/site-packages (from scholarly) (1.0.2)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from scholarly) (0.5.1)
# Requirement already satisfied: PySocks in /opt/conda/lib/python3.7/site-packages (from scholarly) (1.6.8)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from scholarly) (3.7.4.3)
# Requirement already satisfied: requests[security] in /opt/conda/lib/python3.7/site-packages (from scholarly) (2.21.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from scholarly) (4.7.1)
# Requirement already satisfied: fake-useragent in /opt/conda/lib/python3.7/site-packages (from scholarly) (0.1.11)
# Requirement already satisfied: bibtexparser in /opt/conda/lib/python3.7/site-packages (from scholarly) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /opt/conda/lib/python3.7/site-packages (from arrow->scholarly) (2.8.0)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.7/site-packages (from selenium->scholarly) (1.24.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.7/site-packages (from free-proxy->scholarly) (4.6.2)
# Requirement already satisfied: sphinx in /opt/conda/lib/python3.7/site-packages (from sphinx-rtd-theme->scholarly) (3.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests[security]->scholarly) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests[security]->scholarly) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests[security]->scholarly) (2019.3.9)
# Requirement already satisfied: cryptography>=1.3.4; extra == "security" in /opt/conda/lib/python3.7/site-packages (from requests[security]->scholarly) (2.6.1)
# Requirement already satisfied: pyOpenSSL>=0.14; extra == "security" in /opt/conda/lib/python3.7/site-packages (from requests[security]->scholarly) (19.0.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->scholarly) (1.9.1)
# Requirement already satisfied: future>=0.16.0 in /opt/conda/lib/python3.7/site-packages (from bibtexparser->scholarly) (0.18.2)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/conda/lib/python3.7/site-packages (from bibtexparser->scholarly) (2.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (41.0.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.1.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (19.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.0.3)
# Requirement already satisfied: sphinxcontrib-devhelp in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: Jinja2>=2.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (2.10.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (0.7.12)
# Requirement already satisfied: snowballstemmer>=1.1 in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (2.1.0)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (2.9.0)
# Requirement already satisfied: imagesize in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.2.0)
# Requirement already satisfied: docutils>=0.12 in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (0.16)
# Requirement already satisfied: sphinxcontrib-qthelp in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->sphinx-rtd-theme->scholarly) (2.4.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/conda/lib/python3.7/site-packages (from cryptography>=1.3.4; extra == "security"->requests[security]->scholarly) (1.12.3)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/conda/lib/python3.7/site-packages (from cryptography>=1.3.4; extra == "security"->requests[security]->scholarly) (0.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from Jinja2>=2.3->sphinx->sphinx-rtd-theme->scholarly) (1.1.1)
# Requirement already satisfied: pytz>=2015.7 in /opt/conda/lib/python3.7/site-packages (from babel>=1.3->sphinx->sphinx-rtd-theme->scholarly) (2019.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3.4; extra == "security"->requests[security]->scholarly) (2.19)

# %%
#!pip install openpyxl
#!pip install spacy
#!pip install fuzzywuzzy
#!pip install python-Levenshtein
#import nltk; nltk.download('words')

# import packages
import imp, importlib # For working with modules
import pandas as pd # for working with dataframes
import numpy as np # for working with numbers
import pickle # For working with .pkl files
import re # for regex magic
from tqdm import tqdm # Shows progress over iterations, including in pandas via "progress_apply"
import sys # For terminal tricks
import _pickle as cPickle # Optimized version of pickle
import gc # For managing garbage collector
import timeit # For counting time taken for a process
import datetime # For working with dates & times
from datetime import date
import openpyxl # for saving in excel format
from scholarly import scholarly # For checking article pub year
import tables
from fuzzywuzzy import fuzz, process
import random
from time import sleep
import os; from os import listdir; from os.path import isfile, join
from quickpickle import quickpickle_dump, quickpickle_load # custom scripts for quick saving & loading to pickle format

# %%
# define filepaths

thisday = date.today().strftime("%m%d%y")

cwd = os.getcwd()
root = str.replace(cwd, 'classification/preprocess', '')

ocr_fp = root + 'jstor_data/ocr/' # text files
data_fp = root + 'classification/data/' # public data files (no raw JSTOR data)
storage_fp = root + 'models_storage/'# private repo for output files (contains JSTOR data)

# Current article lists
article_list_fp = data_fp + 'filtered_length_index.csv' # Filtered index of research articles
article_paths_fp = data_fp + 'filtered_length_article_paths.csv' # List of article file paths
article_names_fp = data_fp + 'filtered_length_article_names.xlsx' # Filtered list of article names and general data, sorted by journal then article name

# dictionary counts (using core dictionaries) and matched subjects 
counts_fp = root + 'dictionary_methods/counts_and_subject.csv'

# per-article metadata with URLs
meta_fp = storage_fp + 'metadata/metadata_combined_030921.h5' 

# per-article info on cosine scores using each dictionary (core or 100-term dictionaries??)
cosines_fp = storage_fp + 'word_embeddings_data/text_with_cosine_scores_wdg_2020_oct27.csv'

# sample of 55 articles with hand-checked years
checked_fp = data_fp + 'coded_year_checked_02_2021.xlsx'

# %% [markdown]
# ## Read in & merge data

# %%
# Read in metadata file
df_meta = pd.read_hdf(meta_fp)
df_meta.reset_index(drop=False, inplace=True) # extract file name from index

# For merging purposes, get ID alone from file name, e.g. 'journal-article-10.2307_2065002' -> '10.2307_2065002'
df_meta['edited_filename'] = df_meta['file_name'].apply(lambda x: x[16:]) 
df_meta = df_meta[["edited_filename", "article_name", "jstor_url", "abstract", "journal_title", "given_names", "primary_subject", "year", "type"]] # keep only relevant columns
df_meta.rename(columns={'year':'year_jstor_new'}, inplace = True)

df_meta.head()
# Out:
#     edited_filename                                       article_name  \
# 0   10.2307_4167860  Cross-Dialectal Variation in Arabic: Competing...
# 1   10.2307_2578336                                               None
# 2   10.2307_2654760                                               None
# 3  10.2307_43242281                     editor's note: A KNIGHT'S TALE
# 4  10.2307_42862018                                               None
#
#                                jstor_url  \
# 0   https://www.jstor.org/stable/4167860
# 1   https://www.jstor.org/stable/2578336
# 2   https://www.jstor.org/stable/2654760
# 3  https://www.jstor.org/stable/43242281
# 4  https://www.jstor.org/stable/42862018
#
#                                             abstract  \
# 0  Most researchers of Arabic sociolinguistics as...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#               journal_title  \
# 0       Language in Society
# 1             Social Forces
# 2    Contemporary Sociology
# 3         Corporate Knights
# 4  Social Science Quarterly
#
#                                          given_names primary_subject  \
# 0                                               None           Other
# 1  [Sidney, Hyman P., Riv-Ellen, Stephen, Thomas,...       Sociology
# 2  [Sidney, Hyman P., Riv-Ellen, Stephen, Thomas,...       Sociology
# 3  [Sidney, Hyman P., Riv-Ellen, Stephen, Thomas,...           Other
# 4  [Sidney, Hyman P., Riv-Ellen, Stephen, Thomas,...       Sociology
#
#   year_jstor_new              type
# 0           1979  research-article
# 1           1983       book-review
# 2           1998       book-review
# 3           2005              misc
# 4           1985       book-review

# %%
# Read in filtered index, counts
df = pd.read_csv(article_list_fp, low_memory=False, header=None, names=["file_name"])
df['edited_filename'] = df['file_name'].apply(lambda x: x[16:]) # New col with only article ID

df_counts = pd.read_csv(counts_fp, low_memory=False)
df_counts['edited_filename'] = df_counts['article_id'].apply(lambda x: x[16:]) # New col with only article ID
df_counts = df_counts[['edited_filename', 'word_count']]

# Merge meta data, counts into articles list DF
df = pd.merge(df, df_meta, how='left', on='edited_filename') # meta data
df = pd.merge(df, df_counts, how='left', on='edited_filename') # counts

# Eliminate empty rows
df = df[df['article_name'].notnull()]

# %%
# Read hand-checked article sample
checked_df = pd.read_excel(checked_fp)
checked_df = checked_df[['edited_filename', 'year_hand_checked', 'year_jstor_dfr']]
checked_df.rename(columns={'year_jstor_dfr':'year_jstor_old'}, inplace = True)

# Limit to just this sample
df = pd.merge(df, checked_df, how='right', on='edited_filename')
              
# Show all columns in resulting DF
print("All columns:\n", list(df))
print()

print("Rows, cols in data:", df.shape)

df.head()
# Out:
# All columns:
#  ['file_name', 'edited_filename', 'article_name', 'jstor_url', 'abstract', 'journal_title', 'given_names', 'primary_subject', 'year_jstor_new', 'type', 'word_count', 'year_hand_checked', 'year_jstor_old']
#
# Rows, cols in data: (55, 13)
#                           file_name   edited_filename  \
# 0  journal-article-10.2307_41275157  10.2307_41275157
# 1  journal-article-10.2307_29770169  10.2307_29770169
# 2  journal-article-10.2307_20460016  10.2307_20460016
# 3   journal-article-10.2307_2112560   10.2307_2112560
# 4   journal-article-10.2307_2635073   10.2307_2635073
#
#                                         article_name  \
# 0  Foucault Reads Freud: The Dialogue with Unreas...
# 1  A Socio-instutionalist Critique of the 1990s' ...
# 2  Changes in the Practice of Eating: A Comparati...
# 3  Collective Bargaining and Faculty Compensation...
# 4  Windows of Opportunity: Temporal Patterns of T...
#
#                                jstor_url  \
# 0  https://www.jstor.org/stable/41275157
# 1  https://www.jstor.org/stable/29770169
# 2  https://www.jstor.org/stable/20460016
# 3   https://www.jstor.org/stable/2112560
# 4   https://www.jstor.org/stable/2635073
#
#                                             abstract  \
# 0  The title of the essay refers to the famous st...
# 1  This paper argues that the on-going reforms to...
# 2  This article examines changes in aspects of th...
# 3  This article assesses the impact of the unioni...
# 4  This paper examines the introduction and adapt...
#
#                 journal_title  \
# 0  Polish Sociological Review
# 1    Review of Social Economy
# 2            Acta Sociologica
# 3      Sociology of Education
# 4        Organization Science
#
#                                          given_names  \
# 0  [Loren C., Jeffrey, Stephen, Gerrie ter, Mathi...
# 1  [Jack W., A. Harvey, Christopher, Michael G., ...
# 2  [Sandra H., David E., Christoph, Martine, Arno...
# 3  [Mabel, David, Jorge A., Benito E., Danièle, L...
# 4  [Arthur, Alan R., Georg, K., E., Yaniv, Stephe...
#
#                         primary_subject year_jstor_new              type  \
# 0                             Sociology           2010  research-article
# 1                             Sociology           2002  research-article
# 2                             Sociology           2007  research-article
# 3                             Sociology           1980  research-article
# 4  Management & Organizational Behavior           1986  research-article
#
#    word_count  year_hand_checked  year_jstor_old
# 0        6943               2010            2010
# 1        8969               2002            2002
# 2        9074               2007            2007
# 3        6366               1987            1980
# 4       10514               1994            1986

# %% [markdown]
# ## Correct publication year using APIs

# %% [markdown]
# ### Scholarly API (breaks)

# %%
def get_year_scholarly(title):
    '''
    Gets publication year for article using title, using the Scholarly API (which uses Google Scholar). 
    
    Args:
        title (str): full title, e.g., 'The Collective Strategy Framework: An Application to Competing Predictions of Isomorphism'
        
    Returns:
        pub_year (int): year article was published, in four digits (i.e., `19xx` or `20xx`)
    '''
    
    search_query = scholarly.search_pubs(title)
    
    pub_year = next(search_query)['bib']['pub_year']
    
    sleep(random.randint(200,500)/100) # random pause to avoid getting blocked by Google
    
    return pub_year

# %%
# Test Scholarly API (gets blocked by Google via `MaxTriesExceedException`)
title_year_tups = [
    ("A Socio-instutionalist Critique of the 1990s' Reforms of the United Kingdom's National Health Service", 2002, 2002), 
    ("Deepening Our Commitment, Hitting the Streets: A Call to Action", 2001, 2001), 
    ("Linking Organizational Values to Relationships with External Constituents: A Study of Nonprofit Professional Theatres", 2000, 1995), 
    ("On the Foundations of Athenian Democracy: Marx's Paradox and Weber's Solution", 2000, 2000), 
    ("Consumption Caught in the 'Cash Nexus'", 2000, 2000), 
    ("Culture and Charisma: Outline of a Theory", 2000, 1971), 
    ("The Collective Strategy Framework: An Application to Competing Predictions of Isomorphism", 1988, 1984), 
    ("Windows of Opportunity: Temporal Patterns of Technological Adaptation in Organizations", 1994, 1986), 
    ("The Gentle Leviathan: Welfare and the Indian State", 1994, 1987)]

for title, true_year, jstor_year in title_year_tups:
    retrieved_year = get_year_scholarly(title)
    print("Title: \t\t\t\t{}".format(title))
    print("Verified pub year: \t\t{}".format(str(true_year)))
    print("Pub year from Scholarly: \t{}".format(str(get_year_scholarly(title))))
    #print("Pub year from Web of Science: \t{}".format(str(get_year_webofscience(title))))
    print("Pub year from JSTOR: \tnext(search_query)['bib']['pub_year']\t{}".format(str(jstor_year)))
    print()
# Out:
# Title: 				A Socio-instutionalist Critique of the 1990s' Reforms of the United Kingdom's National Health Service
# Verified pub year: 		2002
# Pub year from Scholarly: 	2002
# Pub year from JSTOR: 	next(search_query)['bib']['pub_year']	2002
#
# Title: 				Deepening Our Commitment, Hitting the Streets: A Call to Action
# Verified pub year: 		2001
# Pub year from Scholarly: 	2001
# Pub year from JSTOR: 	next(search_query)['bib']['pub_year']	2001
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# <ipython-input-10-4cffe82c91a7> in <module>
#      12
#      13 for title, true_year, jstor_year in title_year_tups:
# ---> 14     retrieved_year = get_year_scholarly(title)
#      15     print("Title: \t\t\t\t{}".format(title))
#      16     print("Verified pub year: \t\t{}".format(str(true_year)))
#
# <ipython-input-9-07d63d1c0c7a> in get_year_scholarly(title)
#      10     '''
#      11
# ---> 12     search_query = scholarly.search_pubs(title)
#      13
#      14     pub_year = next(search_query)['bib']['pub_year']
#
# /opt/conda/lib/python3.7/site-packages/scholarly/_scholarly.py in search_pubs(self, query, patents, citations, year_low, year_high, sort_by, include_last_year)
#     143         # improve str below
#     144         url = url + yr_lo + yr_hi + citations + patents + sortby
# --> 145         return self.__nav.search_publications(url)
#     146
#     147     def search_single_pub(self, pub_title: str, filled: bool = False)->PublicationParser:
#
# /opt/conda/lib/python3.7/site-packages/scholarly/_navigator.py in search_publications(self, url)
#     261         :rtype: {_SearchScholarIterator}
#     262         """
# --> 263         return _SearchScholarIterator(self, url)
#     264
#     265     def search_author_id(self, id: str, filled: bool = False, sortby: str = "citedby", publication_limit: int = 0) -> Author:
#
# /opt/conda/lib/python3.7/site-packages/scholarly/publication_parser.py in __init__(self, nav, url)
#      51         self._url = url
#      52         self._nav = nav
# ---> 53         self._load_url(url)
#      54         self.total_results = self._get_total_results()
#      55         self.pub_parser = PublicationParser(self._nav)
#
# /opt/conda/lib/python3.7/site-packages/scholarly/publication_parser.py in _load_url(self, url)
#      57     def _load_url(self, url: str):
#      58         # this is temporary until setup json file
# ---> 59         self._soup = self._nav._get_soup(url)
#      60         self._pos = 0
#      61         self._rows = self._soup.find_all('div', class_='gs_r gs_or gs_scl')
#
# /opt/conda/lib/python3.7/site-packages/scholarly/_navigator.py in _get_soup(self, url)
#     204     def _get_soup(self, url: str) -> BeautifulSoup:
#     205         """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 206         html = self._get_page('https://scholar.google.com{0}'.format(url))
#     207         html = html.replace(u'\xa0', u' ')
#     208         res = BeautifulSoup(html, 'html.parser')
#
# /opt/conda/lib/python3.7/site-packages/scholarly/_navigator.py in _get_page(self, pagerequest)
#     156             tries += 1
#     157             self._session, timeout = self.pm.get_next_proxy(num_tries = tries, old_timeout = timeout)
# --> 158         raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#     159
#     160
#
# MaxTriesExceededException: Cannot Fetch from Google Scholar.

# %% [markdown]
# ### Web of Science API

# %%
# Setup API
import woslite_client
from woslite_client.rest import ApiException
from pprint import pprint

def load_api_key(path):
    '''
    Loads text from file containing API key.
    '''
    with open(path, 'r') as f:
        for line in f:
            return line.strip()
        
# Configure API key authorization
configuration = woslite_client.Configuration()
configuration.api_key['X-ApiKey'] = load_api_key('wos_api_key.txt')

# Create an instance of the API class
integration_api_instance = woslite_client.IntegrationApi(woslite_client.ApiClient(configuration))
search_api_instance = woslite_client.SearchApi(woslite_client.ApiClient(configuration))
database_id = 'WOK'  # str | Database to search. Must be a valid database ID, one of the following: BCI/BIOABS/BIOSIS/CCC/DCI/DIIDW/MEDLINE/WOK/WOS/ZOOREC. WOK represents all databases.

# %%
def get_year_wos(row): 

    '''
    Gets publication year for article using title, using the Scholarly API (which uses Google Scholar). 
    
    Docs: https://github.com/Clarivate-SAR/woslite_py_client
    
    Args:
        row (Series): first element is full title, e.g., 'The Collective Strategy Framework: An Application to Competing Predictions of Isomorphism'; second element is journal title
        
    Returns:
        pub_year (int): year article was published, in four digits (i.e., `19xx` or `20xx`)
    '''
    
    sleeptime = 1 #random.randint(5000,7000)/1000  # set pause for politeness/to avoid getting blocked by API
    title = row[0] # get title #title_col
    journal = row[1] # get journal #journal_col
    
    # Configure query
    title = title.replace("'", "") # remove apostrophes (confuses parser)
    usr_query = f"TI=({title}) AND SO=({journal})" # str | User query for requesting data, ex: TS=(cadmium). The query parser will return errors for invalid queries.
    count = 1  # int | Number of records returned in the request
    first_record = 1  # int | Specific record, if any within the result set to return. Cannot be less than 1 and greater than 100000.
    lang = 'en'  # str | Language of search. This element can take only one value: en for English. If no language is specified, English is passed by default. (optional)
    sort_field = 'PY+D'  # str | Order by field(s). Field name and order by clause separated by '+', use A for ASC and D for DESC, ex: PY+D. Multiple values are separated by comma. (optional)
    
    try:
        # Find record(s) by user query
        api_response = search_api_instance.root_get(database_id, usr_query, count, first_record, lang=lang,
                                                                 sort_field=sort_field)
        
        # Get fields of interest from API response, assign to row
        pub_year = api_response.data[0].source.published_biblio_year[0]
        pub_title = api_response.data[0].title.title[0]
        similarity = fuzz.ratio(title.lower(), pub_title.lower()) # compare titles
        
        #print(f'API record found for: \t"{pub_title}"') # show results
        #print(f'JSTOR Title for above:\t"{title}"')
        sleep(sleeptime) # pause
        
        return pd.Series([pub_year, pub_title, similarity])
        
    except Exception as e:
        print("API failed with error: \t%s" % e)
        sleep(sleeptime) # pause
        
        return pd.Series([np.NaN, np.NaN, np.NaN])

# %%
# Execute WOS method
tqdm.pandas(desc='API -> year...')

try:
    df[['year_wos', 'article_name_wos', 'similarity_wos_title']] = df[['article_name', 'journal_title']].progress_apply(get_year_wos, axis=1)
except ValueError as e: 
    print(f'Encountered error: {e}')
# Out:
# API -> year...:   0%|          | 0/55 [00:00<?, ?it/s]
# API record found for: 	"Foucault Reads Freud: The Dialogue with Unreason and Enlightenment"
# JSTOR Title for above:	"Foucault Reads Freud: The Dialogue with Unreason and Enlightenment"
# API -> year...:   4%|▎         | 2/55 [00:01<00:30,  1.72it/s]
# API record found for: 	"Foucault Reads Freud: The Dialogue with Unreason and Enlightenment"
# JSTOR Title for above:	"Foucault Reads Freud: The Dialogue with Unreason and Enlightenment"
# API -> year...:   5%|▌         | 3/55 [00:02<00:42,  1.23it/s]
# API failed with error: 	list index out of range
# API -> year...:   7%|▋         | 4/55 [00:03<00:47,  1.07it/s]
# API record found for: 	"Changes in the practice of eating - A comparative analysis of time-use"
# JSTOR Title for above:	"Changes in the Practice of Eating: A Comparative Analysis of Time-Use"
# API -> year...:   9%|▉         | 5/55 [00:04<00:51,  1.02s/it]
# API record found for: 	"COLLECTIVE-BARGAINING AND FACULTY COMPENSATION - FACULTY AS A NEW WORKING-CLASS"
# JSTOR Title for above:	"Collective Bargaining and Faculty Compensation: Faculty as a New Working Class"
# API -> year...:  11%|█         | 6/55 [00:05<00:53,  1.09s/it]
# API record found for: 	"WINDOWS OF OPPORTUNITY - TEMPORAL PATTERNS OF TECHNOLOGICAL ADAPTATION IN ORGANIZATIONS"
# JSTOR Title for above:	"Windows of Opportunity: Temporal Patterns of Technological Adaptation in Organizations"
# API -> year...:  13%|█▎        | 7/55 [00:07<00:54,  1.14s/it]
# API record found for: 	"DRAMATURGY AND POLITICAL MYSTIFICATION - POLITICAL LIFE IN THE UNITED-STATES"
# JSTOR Title for above:	"DRAMATURGY AND POLITICAL MYSTIFICATION: POLITICAL LIFE IN THE UNITED STATES"
# API -> year...:  15%|█▍        | 8/55 [00:08<00:55,  1.17s/it]
# API record found for: 	"Commanding materials: (Re)legitimating authority in the context of multi-disciplinary work"
# JSTOR Title for above:	"Commanding Materials: (Re)legitimating Authority in the Context of Multi-disciplinary Work"
# API -> year...:  16%|█▋        | 9/55 [00:09<00:53,  1.16s/it]
# API record found for: 	"ANONYMITY AND THE RISE OF UNIVERSAL OCCASIONS FOR RELIGIOUS RITUAL - AN EXTENSION OF THE DURKHEIMIAN THEORY"
# JSTOR Title for above:	"Anonymity and the Rise of Universal Occasions for Religious Ritual: An Extension of the Durkheimian Theory"
# API -> year...:  18%|█▊        | 10/55 [00:10<00:52,  1.16s/it]
# API record found for: 	"Constructing Clean Dreams: Accounts, Future Selves, and Social and Structural Support as Desistance Work"
# JSTOR Title for above:	"Constructing Clean Dreams: Accounts, Future Selves, and Social and Structural Support as Desistance Work"
# API -> year...:  20%|██        | 11/55 [00:11<00:50,  1.16s/it]
# API record found for: 	"Being Special, Becoming Indigenous: Dilemmas of Special Adat Rights in Indonesia"
# JSTOR Title for above:	"Being Special, Becoming Indigenous: Dilemmas of Special Adat Rights in Indonesia"
# API -> year...:  22%|██▏       | 12/55 [00:12<00:49,  1.15s/it]
# API record found for: 	"Culture and charisma: Outline of a theory"
# JSTOR Title for above:	"Culture and Charisma: Outline of a Theory"
# API -> year...:  24%|██▎       | 13/55 [00:14<00:48,  1.15s/it]
# API failed with error: 	list index out of range
# API -> year...:  25%|██▌       | 14/55 [00:15<00:46,  1.14s/it]
# API record found for: 	"Consumption caught in the 'cash nexus'"
# JSTOR Title for above:	"Consumption Caught in the Cash Nexus"
# API -> year...:  27%|██▋       | 15/55 [00:16<00:45,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  29%|██▉       | 16/55 [00:17<00:45,  1.18s/it]
# API record found for: 	"Civil society and agricultural sustainability"
# JSTOR Title for above:	"Civil Society and Agricultural Sustainability"
# API -> year...:  31%|███       | 17/55 [00:18<00:46,  1.21s/it]
# API failed with error: 	list index out of range
# API -> year...:  33%|███▎      | 18/55 [00:20<00:44,  1.22s/it]
# API record found for: 	""Brainwashing" theories in European parliamentary and administrative reports on "cults" and "sects""
# JSTOR Title for above:	""Brainwashing" Theories in European Parliamentary and Administrative Reports on "Cults" and "Sects""
# API -> year...:  35%|███▍      | 19/55 [00:21<00:43,  1.19s/it]
# API record found for: 	"CONCEPTUALIZING RACISMS - SOCIAL-THEORY, POLITICS AND RESEARCH"
# JSTOR Title for above:	"CONCEPTUALISING RACISMS: SOCIAL THEORY, POLITICS AND RESEARCH"
# API -> year...:  36%|███▋      | 20/55 [00:22<00:41,  1.18s/it]
# API record found for: 	"Deepening our commitment, hitting the streets: A call to action"
# JSTOR Title for above:	"Deepening Our Commitment, Hitting the Streets: A Call to Action"
# API -> year...:  38%|███▊      | 21/55 [00:23<00:39,  1.17s/it]
# API failed with error: 	list index out of range
# API -> year...:  40%|████      | 22/55 [00:24<00:38,  1.16s/it]
# API failed with error: 	list index out of range
# API -> year...:  42%|████▏     | 23/55 [00:25<00:36,  1.15s/it]
# API failed with error: 	list index out of range
# API -> year...:  44%|████▎     | 24/55 [00:26<00:35,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  45%|████▌     | 25/55 [00:28<00:34,  1.14s/it]
# API record found for: 	"How the civil rights movement revitalized labor militancy. (vol 67, pg 723, 2002)"
# JSTOR Title for above:	"How the Civil Rights Movement Revitalized Labor Militancy"
# API -> year...:  47%|████▋     | 26/55 [00:29<00:33,  1.15s/it]
# API record found for: 	"The Production and Transmission of Knowledge in Colonial Malaya"
# JSTOR Title for above:	"The Production and Transmission of Knowledge in Colonial Malaya"
# API -> year...:  49%|████▉     | 27/55 [00:30<00:32,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  51%|█████     | 28/55 [00:31<00:31,  1.17s/it]
# API record found for: 	"Board-Management Relationships: Resources and Internal Dynamics"
# JSTOR Title for above:	"Board-Management Relationships: Resources and Internal Dynamics"
# API -> year...:  53%|█████▎    | 29/55 [00:32<00:30,  1.16s/it]
# API failed with error: 	list index out of range
# API -> year...:  55%|█████▍    | 30/55 [00:33<00:28,  1.15s/it]
# API record found for: 	"Health and quality of life of older people, a replication after six years"
# JSTOR Title for above:	"Health and quality of life of older people, a replication after six years"
# API -> year...:  56%|█████▋    | 31/55 [00:35<00:27,  1.15s/it]
# API failed with error: 	list index out of range
# API -> year...:  58%|█████▊    | 32/55 [00:36<00:26,  1.15s/it]
# API failed with error: 	list index out of range
# API -> year...:  60%|██████    | 33/55 [00:37<00:25,  1.14s/it]
# API record found for: 	"Race and theory: Culture, poverty, and adaptation to discrimination in Wilson and Ogbu"
# JSTOR Title for above:	"Race and Theory: Culture, Poverty, and Adaptation to Discrimination in Wilson and Ogbu"
# API -> year...:  62%|██████▏   | 34/55 [00:38<00:24,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  64%|██████▎   | 35/55 [00:39<00:22,  1.14s/it]
# API record found for: 	"An analysis of Zimbabwean hotel managers' perspectives on workforce diversity"
# JSTOR Title for above:	"An analysis of Zimbabwean hotel managers perspectives on workforce diversity"
# API -> year...:  65%|██████▌   | 36/55 [00:40<00:21,  1.14s/it]
# API record found for: 	"Organizational foundings in community context: Instruments manufacturers and their interrelationship with other organizations"
# JSTOR Title for above:	"Organizational Foundings in Community Context: Instruments Manufacturers and Their Interrelationship with Other Organizations"
# API -> year...:  67%|██████▋   | 37/55 [00:41<00:20,  1.14s/it]
# API record found for: 	"From Experience to Experiential Learning: Cultural Intelligence as a Learning Capability for Global Leader Development"
# JSTOR Title for above:	"From Experience to Experiential Learning: Cultural Intelligence as a Learning Capability for Global Leader Development"
# API -> year...:  69%|██████▉   | 38/55 [00:43<00:19,  1.14s/it]
# API record found for: 	"Change and complementarities in the new competitive landscape: A European panel study, 1992-1996"
# JSTOR Title for above:	"Change and Complementarities in the New Competitive Landscape: A European Panel Study, 1992-1996"
# API -> year...:  71%|███████   | 39/55 [00:44<00:18,  1.15s/it]
# API record found for: 	"Bad apples or bad barrels? A former CEO discusses the interplay of person and situation with implications for business education"
# JSTOR Title for above:	"Bad Apples or Bad Barrels? A Former CEO Discusses the Interplay of Person and Situation with Implications for Business Education"
# API -> year...:  73%|███████▎  | 40/55 [00:45<00:17,  1.14s/it]
# API record found for: 	"Nazism, nationalism, and the sociology of emotions: Escape from Freedom revisited"
# JSTOR Title for above:	"Nazism, Nationalism, and the Sociology of Emotions: Escape from Freedom Revisited"
# API -> year...:  75%|███████▍  | 41/55 [00:46<00:16,  1.14s/it]
# API record found for: 	"Sports in civil society: Networks, social capital and influence"
# JSTOR Title for above:	"Sports in Civil Society: Networks, Social Capital and Influence"
# API -> year...:  76%|███████▋  | 42/55 [00:47<00:14,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  78%|███████▊  | 43/55 [00:48<00:13,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  80%|████████  | 44/55 [00:49<00:12,  1.14s/it]
# API record found for: 	"Family Complexity and Children's Behavior Problems over Two US Cohorts"
# JSTOR Title for above:	"The Impact of the First Birth: Married and Single Women Preferring Childlessness, One Child, or Two Children"
# API -> year...:  82%|████████▏ | 45/55 [00:50<00:11,  1.14s/it]
# API record found for: 	"Linking organizational values to relationships with external constituents: A study of nonprofit professional theatres"
# JSTOR Title for above:	"Linking Organizational Values to Relationships with External Constituents: A Study of Nonprofit Professional Theatres"
# API -> year...:  84%|████████▎ | 46/55 [00:52<00:10,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  85%|████████▌ | 47/55 [00:53<00:09,  1.14s/it]
# API record found for: 	"Disparities in Academic Achievement: Assessing the Role of Habitus and Practice"
# JSTOR Title for above:	"Disparities in Academic Achievement: Assessing the Role of Habitus and Practice"
# API -> year...:  87%|████████▋ | 48/55 [00:54<00:07,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  89%|████████▉ | 49/55 [00:55<00:06,  1.14s/it]
# API record found for: 	"WHEN EXPERIENCE MEETS NATIONAL INSTITUTIONAL ENVIRONMENTAL CHANGE: FOREIGN ENTRY ATTEMPTS OF US FIRMS IN THE CENTRAL AND EASTERN EUROPEAN REGION"
# JSTOR Title for above:	"When Experience Meets National Institutional Environmental Change: Foreign Entry Attempts of U.S. Firms in the Central and Eastern European Region"
# API -> year...:  91%|█████████ | 50/55 [00:56<00:05,  1.14s/it]
# API record found for: 	"Knowledge management and organisational culture in higher education institutions"
# JSTOR Title for above:	"Knowledge management and organisational culture in higher education institutions"
# API -> year...:  93%|█████████▎| 51/55 [00:57<00:04,  1.14s/it]
# API failed with error: 	list index out of range
# API -> year...:  95%|█████████▍| 52/55 [00:59<00:03,  1.17s/it]
# API record found for: 	"Non-profit foundations in four countries of central and eastern Europe"
# JSTOR Title for above:	"Non-Profit Foundations in Four Countries of Central and Eastern Europe"
# API -> year...:  96%|█████████▋| 53/55 [01:00<00:02,  1.19s/it]
# API record found for: 	"SHAS as a struggle to create a new field: A Bourdieuan perspective of an Israeli phenomenon"
# JSTOR Title for above:	"SHAS as a Struggle to Create a New Field: A Bourdieuan Perspective of an Israeli Phenomenon"
# API -> year...:  98%|█████████▊| 54/55 [01:01<00:01,  1.18s/it]
# API failed with error: 	list index out of range
# API -> year...: 100%|██████████| 55/55 [01:02<00:00,  1.17s/it]
# API failed with error: 	list index out of range
# API record found for: 	"THE COLLECTIVE STRATEGY FRAMEWORK - AN APPLICATION TO COMPETING PREDICTIONS OF ISOMORPHISM"
# JSTOR Title for above:	"The Collective Strategy Framework: An Application to Competing Predictions of Isomorphism"
# API -> year...: 100%|██████████| 55/55 [01:04<00:00,  1.18s/it]

# %%
df
# Out:
#                                    file_name           edited_filename  \
# 0           journal-article-10.2307_41275157          10.2307_41275157
# 1           journal-article-10.2307_29770169          10.2307_29770169
# 2           journal-article-10.2307_20460016          10.2307_20460016
# 3            journal-article-10.2307_2112560           10.2307_2112560
# 4            journal-article-10.2307_2635073           10.2307_2635073
# 5           journal-article-10.2307_23252765          10.2307_23252765
# 6           journal-article-10.2307_42858192          10.2307_42858192
# 7            journal-article-10.2307_1387003           10.2307_1387003
# 8    journal-article-10.1525_si.2011.34.1.63   10.1525_si.2011.34.1.63
# 9           journal-article-10.2307_43497847          10.2307_43497847
# 10           journal-article-10.2307_4201192           10.2307_4201192
# 11          journal-article-10.2307_42856982          10.2307_42856982
# 12          journal-article-10.2307_42856225          10.2307_42856225
# 13          journal-article-10.2307_23261799          10.2307_23261799
# 14          journal-article-10.2307_42863819          10.2307_42863819
# 15          journal-article-10.2307_23262586          10.2307_23262586
# 16           journal-article-10.2307_1387941           10.2307_1387941
# 17          journal-article-10.2307_42855320          10.2307_42855320
# 18  journal-article-10.1525_sp.2001.48.1.152  10.1525_sp.2001.48.1.152
# 19           journal-article-10.2307_2777054           10.2307_2777054
# 20          journal-article-10.2307_40649317          10.2307_40649317
# 21          journal-article-10.2307_40397128          10.2307_40397128
# 22          journal-article-10.2307_41682289          10.2307_41682289
# 23           journal-article-10.2307_3088915           10.2307_3088915
# 24          journal-article-10.2307_23655208          10.2307_23655208
# 25           journal-article-10.2307_3517911           10.2307_3517911
# 26          journal-article-10.2307_41783571          10.2307_41783571
# 27          journal-article-10.2307_26161684          10.2307_26161684
# 28          journal-article-10.2307_20734512          10.2307_20734512
# 29           journal-article-10.2307_2393869           10.2307_2393869
# 30           journal-article-10.2307_3516389           10.2307_3516389
# 31            journal-article-10.2307_202096            10.2307_202096
# 32          journal-article-10.2307_25822540          10.2307_25822540
# 33          journal-article-10.2307_23745401          10.2307_23745401
# 34          journal-article-10.2307_25426913          10.2307_25426913
# 35          journal-article-10.2307_27759189          10.2307_27759189
# 36           journal-article-10.2307_2640319           10.2307_2640319
# 37          journal-article-10.2307_40214388          10.2307_40214388
# 38           journal-article-10.2307_3045388           10.2307_3045388
# 39          journal-article-10.2307_25209140          10.2307_25209140
# 40          journal-article-10.2307_24579713          10.2307_24579713
# 41          journal-article-10.2307_43572622          10.2307_43572622
# 42            journal-article-10.2307_352393            10.2307_352393
# 43           journal-article-10.2307_2640266           10.2307_2640266
# 44          journal-article-10.2307_40929634          10.2307_40929634
# 45          journal-article-10.2307_24720249          10.2307_24720249
# 46          journal-article-10.2307_23727525          10.2307_23727525
# 47          journal-article-10.2307_27735492          10.2307_27735492
# 48          journal-article-10.2307_23281852          10.2307_23281852
# 49          journal-article-10.2307_20459971          10.2307_20459971
# 50          journal-article-10.2307_41274965          10.2307_41274965
# 51           journal-article-10.2307_3712372           10.2307_3712372
# 52           journal-article-10.2307_2786730           10.2307_2786730
# 53          journal-article-10.2307_40397361          10.2307_40397361
# 54           journal-article-10.2307_2392643           10.2307_2392643
#
#                                          article_name  \
# 0   Foucault Reads Freud: The Dialogue with Unreas...
# 1   A Socio-instutionalist Critique of the 1990s' ...
# 2   Changes in the Practice of Eating: A Comparati...
# 3   Collective Bargaining and Faculty Compensation...
# 4   Windows of Opportunity: Temporal Patterns of T...
# 5   DRAMATURGY AND POLITICAL MYSTIFICATION: POLITI...
# 6   Commanding Materials: (Re)legitimating Authori...
# 7   Anonymity and the Rise of Universal Occasions ...
# 8   Constructing Clean Dreams: Accounts, Future Se...
# 9   Being Special, Becoming Indigenous: Dilemmas o...
# 10          Culture and Charisma: Outline of a Theory
# 11  Can Norms Account for Strategic Action? Inform...
# 12             Consumption Caught in the 'Cash Nexus'
# 13                     Christmas: An American Paradox
# 14      Civil Society and Agricultural Sustainability
# 15                A CRITIQUE OF AUTONOMOUS TECHNOLOGY
# 16  "Brainwashing" Theories in European Parliament...
# 17  CONCEPTUALISING RACISMS: SOCIAL THEORY, POLITI...
# 18  Deepening Our Commitment, Hitting the Streets:...
# 19  Afrikaner Calvinism and Economic Action: The W...
# 20  'System Destroys Trust?'—Regulatory Institutio...
# 21  Culture and Meaning: Making Sense of Conflicti...
# 22  Political Institutional Change, Obsolescing Le...
# 23  How the Civil Rights Movement Revitalized Labo...
# 24  The Production and Transmission of Knowledge i...
# 25  The Gentle Leviathan: Welfare and the Indian S...
# 26  Board-Management Relationships: Resources and ...
# 27  THE POLITICAL ECONOMY OF GENETIC ENGINEERING: ...
# 28  Health and quality of life of older people, a ...
# 29  From Fiefs to Clans and Network Capitalism: Ex...
# 30        Class Character of the Nationalist Movement
# 31  Race and Theory: Culture, Poverty, and Adaptat...
# 32  Intersecting Three Muddy Roads: Stability, Leg...
# 33  An analysis of Zimbabwean hotel managers' pers...
# 34  Organizational Foundings in Community Context:...
# 35  From Experience to Experiential Learning: Cult...
# 36  Change and Complementarities in the New Compet...
# 37  Bad Apples or Bad Barrels? A Former CEO Discus...
# 38  Nazism, Nationalism, and the Sociology of Emot...
# 39  Sports in Civil Society: Networks, Social Capi...
# 40  On the Foundations of Athenian Democracy: Marx...
# 41  European Shiism? Counterpoints from Shiites' o...
# 42  The Impact of the First Birth: Married and Sin...
# 43  Linking Organizational Values to Relationships...
# 44  Who's the Boss? Patterns of Control in Adolesc...
# 45  Disparities in Academic Achievement: Assessing...
# 46  Powerful and free: intraorganizational power a...
# 47  When Experience Meets National Institutional E...
# 48  Knowledge management and organisational cultur...
# 49  Is Friendship Consistent with Competitive Mark...
# 50  Non-Profit Foundations in Four Countries of Ce...
# 51  SHAS as a Struggle to Create a New Field: A Bo...
# 52  Predicting Choices in Asymptotic Decisions: A ...
# 53        Business Ethics and Civil Society in Russia
# 54  The Collective Strategy Framework: An Applicat...
#
#                                             jstor_url  \
# 0               https://www.jstor.org/stable/41275157
# 1               https://www.jstor.org/stable/29770169
# 2               https://www.jstor.org/stable/20460016
# 3                https://www.jstor.org/stable/2112560
# 4                https://www.jstor.org/stable/2635073
# 5               https://www.jstor.org/stable/23252765
# 6               https://www.jstor.org/stable/42858192
# 7                https://www.jstor.org/stable/1387003
# 8   https://www.jstor.org/stable/10.1525/si.2011.3...
# 9               https://www.jstor.org/stable/43497847
# 10               https://www.jstor.org/stable/4201192
# 11              https://www.jstor.org/stable/42856982
# 12              https://www.jstor.org/stable/42856225
# 13              https://www.jstor.org/stable/23261799
# 14              https://www.jstor.org/stable/42863819
# 15              https://www.jstor.org/stable/23262586
# 16               https://www.jstor.org/stable/1387941
# 17              https://www.jstor.org/stable/42855320
# 18  https://www.jstor.org/stable/10.1525/sp.2001.4...
# 19               https://www.jstor.org/stable/2777054
# 20              https://www.jstor.org/stable/40649317
# 21              https://www.jstor.org/stable/40397128
# 22              https://www.jstor.org/stable/41682289
# 23               https://www.jstor.org/stable/3088915
# 24              https://www.jstor.org/stable/23655208
# 25               https://www.jstor.org/stable/3517911
# 26              https://www.jstor.org/stable/41783571
# 27              https://www.jstor.org/stable/26161684
# 28              https://www.jstor.org/stable/20734512
# 29               https://www.jstor.org/stable/2393869
# 30               https://www.jstor.org/stable/3516389
# 31                https://www.jstor.org/stable/202096
# 32              https://www.jstor.org/stable/25822540
# 33              https://www.jstor.org/stable/23745401
# 34              https://www.jstor.org/stable/25426913
# 35              https://www.jstor.org/stable/27759189
# 36               https://www.jstor.org/stable/2640319
# 37              https://www.jstor.org/stable/40214388
# 38               https://www.jstor.org/stable/3045388
# 39              https://www.jstor.org/stable/25209140
# 40              https://www.jstor.org/stable/24579713
# 41              https://www.jstor.org/stable/43572622
# 42                https://www.jstor.org/stable/352393
# 43               https://www.jstor.org/stable/2640266
# 44              https://www.jstor.org/stable/40929634
# 45              https://www.jstor.org/stable/24720249
# 46              https://www.jstor.org/stable/23727525
# 47              https://www.jstor.org/stable/27735492
# 48              https://www.jstor.org/stable/23281852
# 49              https://www.jstor.org/stable/20459971
# 50              https://www.jstor.org/stable/41274965
# 51               https://www.jstor.org/stable/3712372
# 52               https://www.jstor.org/stable/2786730
# 53              https://www.jstor.org/stable/40397361
# 54               https://www.jstor.org/stable/2392643
#
#                                              abstract  \
# 0   The title of the essay refers to the famous st...
# 1   This paper argues that the on-going reforms to...
# 2   This article examines changes in aspects of th...
# 3   This article assesses the impact of the unioni...
# 4   This paper examines the introduction and adapt...
# 5                                                None
# 6   This article explores some specific consequenc...
# 7   In this research, Durkheim's theory of the uni...
# 8   This article investigates the discourse indivi...
# 9   From 1998 onwards Indonesias reform era (refor...
# 10  From the work of Weber onwards charisma has be...
# 11  Success in fishing depends upon knowledge of t...
# 12  During the last thirty years 'consumption' has...
# 13  This is a speculative investigation of an extr...
# 14  Objective. We show how the civil society persp...
# 15  This paper was originally read at the Tenth An...
# 16  This study examines the recent rash of officia...
# 17  This paper explores the changing terms of deba...
# 18                                               None
# 19  This paper examines the relationship between t...
# 20  This article aims to explore public perception...
# 21                                               None
# 22  This paper studies the practice of integration...
# 23  Can newly ascendant social movements revitaliz...
# 24  This article aims to highlight how knowledge p...
# 25                                               None
# 26  This paper investigates directors' relationshi...
# 27  The breakthrough of genetic engineering and th...
# 28  Replicating a survey of 875 people 55 years ol...
# 29  China's rapid economic development is being ac...
# 30                                               None
# 31  This article provides the theoretical resource...
# 32  Several decades of research by multiple academ...
# 33  Human resource management academics have built...
# 34  Combining insights from organizational ecology...
# 35  Although international assignments are recogni...
# 36  This paper addresses three weaknesses in the l...
# 37  Recent corporate scandals have directed public...
# 38  The recent worldwide resurgence of militant na...
# 39  Sports represent the largest category of volun...
# 40  Marx's unresolved reflections in 1857 on the a...
# 41  European Shiism is a neglected area in studies...
# 42  This study examines the impact of a first chil...
# 43  This study explores the organizational values ...
# 44  The goals of this study were to examine longit...
# 45  Bourdieu's theory of cultural and social repro...
# 46  The questions of how shifts occur between iner...
# 47  We develop an institutional change perspective...
# 48  This paper focuses on the higher education are...
# 49  A conventional assumption within sociology of ...
# 50  The paper presents an analysis of roles and vi...
# 51  This article suggests that the SHAS movement s...
# 52  Two models of repetitive choice, the "discrimi...
# 53                                               None
# 54  This paper investigates empirically the compet...
#
#                                         journal_title  \
# 0                          Polish Sociological Review
# 1                            Review of Social Economy
# 2                                    Acta Sociologica
# 3                              Sociology of Education
# 4                                Organization Science
# 5                    Mid-American Review of Sociology
# 6                                           Sociology
# 7        Journal for the Scientific Study of Religion
# 8                                Symbolic Interaction
# 9                     Asian Journal of Social Science
# 10                                   Acta Sociologica
# 11                                          Sociology
# 12                                          Sociology
# 13               Humboldt Journal of Social Relations
# 14                           Social Science Quarterly
# 15               Humboldt Journal of Social Relations
# 16       Journal for the Scientific Study of Religion
# 17                                          Sociology
# 18                                    Social Problems
# 19                      American Journal of Sociology
# 20                         Social Indicators Research
# 21  International Studies of Management & Organiza...
# 22               MIR: Management International Review
# 23                       American Sociological Review
# 24                    Asian Journal of Social Science
# 25                                   Social Scientist
# 26                                   Management Revue
# 27                         Organization & Environment
# 28                         Social Indicators Research
# 29                   Administrative Science Quarterly
# 30                                   Social Scientist
# 31                                Sociological Theory
# 32                       Journal of Managerial Issues
# 33                   Tourism and Hospitality Research
# 34                   Administrative Science Quarterly
# 35         Academy of Management Learning & Education
# 36                               Organization Science
# 37         Academy of Management Learning & Education
# 38                                Sociological Theory
# 39                       European Sociological Review
# 40                                  Max Weber Studies
# 41                                        Ethnicities
# 42                     Journal of Marriage and Family
# 43                               Organization Science
# 44                                   Family Relations
# 45                         Social Indicators Research
# 46                             Strategic Organization
# 47                       Strategic Management Journal
# 48        Journal of East European Management Studies
# 49                                   Acta Sociologica
# 50                         Polish Sociological Review
# 51                              Sociology of Religion
# 52                        Social Psychology Quarterly
# 53  International Studies of Management & Organiza...
# 54                   Administrative Science Quarterly
#
#                                           given_names  \
# 0   [Loren C., Jeffrey, Stephen, Gerrie ter, Mathi...
# 1   [Jack W., A. Harvey, Christopher, Michael G., ...
# 2   [Sandra H., David E., Christoph, Martine, Arno...
# 3   [Mabel, David, Jorge A., Benito E., Danièle, L...
# 4   [Arthur, Alan R., Georg, K., E., Yaniv, Stephe...
# 5   [Hans-Jürgen, Conny Herbert, M. L., Herbert Sp...
# 6   [J. L., L. M., Elizabeth G., Robert Y., Ronald...
# 7   [Michal, Martin, Zora, Miroslav, Grigorij, Joh...
# 8   [Ernest S., Michael, Don, Henry S., Régine, Do...
# 9   [Ernest S., Michael, Don, Henry S., Régine, Do...
# 10  [Alice O., Peter, W. Erwin, Bert, Robert W., C...
# 11  [Loren C., Jeffrey, Stephen, Gerrie ter, Mathi...
# 12  [Loren C., Jeffrey, Stephen, Gerrie ter, Mathi...
# 13  [Werner, Werner, Konrad, Rudi, Paul, Jean, Rob...
# 14  [Warren T., Joseph A., V., Gennady, Sylvie, Be...
# 15  [Arthur, Alan R., Georg, K., E., Yaniv, Stephe...
# 16  [Sandra H., David E., Christoph, Martine, Arno...
# 17  [Warren T., Joseph A., V., Gennady, Sylvie, Be...
# 18  [Nina, Eldar, John, Catherine, CHARLES, Bryan ...
# 19  [Arthur, Alan R., Georg, K., E., Yaniv, Stephe...
# 20  [David, Tina, Henri, James D., Julietta, Wendy...
# 21  [Liat, Michael A., John, Mayer N., John D., Jü...
# 22  [Sidney, Hyman P., Riv-Ellen, Stephen, Thomas,...
# 23  [Dalton E., Jim, ANTHONY D., Jaco, Hugh, Mary ...
# 24  [Luis Escala, Francisco, Dharma, Michel, Patri...
# 25  [Jean, Stanley L., Robert E., Ussama, Leonard,...
# 26  [Kelly, Sanjay K., C., V., M., R., W., R.E., C...
# 27  [Randy, Cecilia, Pierre, Anne, Gurumurthy K., ...
# 28  [JOHN, Michael, Tom, Beth B., Gari, Lola, E., ...
# 29  [Beth T., Mark, Paul, Oscar Uribe, Jacques, Da...
# 30  [Michal, Martin, Zora, Miroslav, Grigorij, Joh...
# 31  [Noëlle, MICHAEL, Wolf F., Eberhard K., Peter,...
# 32  [Jean, Stanley L., Robert E., Ussama, Leonard,...
# 33  [ROBERT, Riziki S., Idris S., Patrick, L. A., ...
# 34  [Warren T., Joseph A., V., Gennady, Sylvie, Be...
# 35  [Will, A. L., A., G. S., Frank J., Kenneth J.,...
# 36  [Kathleen S., Suzanne, Tilak, ROBERT K., LEON,...
# 37  [Mabel, David, Jorge A., Benito E., Danièle, L...
# 38  [Campbell R., Richard B., Neelu Kang, John, Ke...
# 39  [Michal, Martin, Zora, Miroslav, Grigorij, Joh...
# 40  [Sidney, Hyman P., Riv-Ellen, Stephen, Thomas,...
# 41  [JADWIGA, Paul J., Wayne, Charles, WILLIAM V.,...
# 42  [Yves, Jean, Megan, Thomas E., HOMER W., Mary ...
# 43  [Noëlle, MICHAEL, Wolf F., Eberhard K., Peter,...
# 44  [Warren T., Joseph A., V., Gennady, Sylvie, Be...
# 45  [Luis Escala, Francisco, Dharma, Michel, Patri...
# 46  [Michael, Alexander, James P., Douglas S., Jam...
# 47  [Alice O., Peter, W. Erwin, Bert, Robert W., C...
# 48  [Noëlle, MICHAEL, Wolf F., Eberhard K., Peter,...
# 49  [Werner, Werner, Konrad, Rudi, Paul, Jean, Rob...
# 50  [JOHN, Michael, Tom, Beth B., Gari, Lola, E., ...
# 51  [Jean, Stanley L., Robert E., Ussama, Leonard,...
# 52  [Mary R., Albert W., Helen, R. A., Judith R., ...
# 53  [David A., Larry, Rainer, Stephan, Robert E., ...
# 54  [Duncan L., Melvin, DAVID L., Andrew, Paul R.,...
#
#                          primary_subject year_jstor_new              type  \
# 0                              Sociology           2010  research-article
# 1                              Sociology           2002  research-article
# 2                              Sociology           2007  research-article
# 3                              Sociology           1980  research-article
# 4   Management & Organizational Behavior           1986  research-article
# 5                              Sociology           1985  research-article
# 6                              Sociology           2004  research-article
# 7                              Sociology           1981  research-article
# 8                              Sociology           2011  research-article
# 9                              Sociology           2011  research-article
# 10                             Sociology           1971  research-article
# 11                             Sociology           2007  research-article
# 12                             Sociology           2000  research-article
# 13                             Sociology           1977  research-article
# 14                             Sociology           1998  research-article
# 15                             Sociology           1985  research-article
# 16                             Sociology           1984  research-article
# 17                             Sociology           1994  research-article
# 18                             Sociology           2001  research-article
# 19                             Sociology           1975  research-article
# 20                             Sociology           2010  research-article
# 21  Management & Organizational Behavior           1989  research-article
# 22  Management & Organizational Behavior           2012  research-article
# 23                             Sociology           1986  research-article
# 24                             Sociology           2009  research-article
# 25                             Sociology           1987  research-article
# 26  Management & Organizational Behavior           2008  research-article
# 27  Management & Organizational Behavior           1998  research-article
# 28                             Sociology           2007  research-article
# 29  Management & Organizational Behavior           1986  research-article
# 30                             Sociology           1975  research-article
# 31                             Sociology           1999  research-article
# 32  Management & Organizational Behavior           2011  research-article
# 33  Management & Organizational Behavior           2010  research-article
# 34  Management & Organizational Behavior           2006  research-article
# 35  Management & Organizational Behavior           2009  research-article
# 36  Management & Organizational Behavior           1992  research-article
# 37  Management & Organizational Behavior           2006  research-article
# 38                             Sociology           1994  research-article
# 39                             Sociology           2008  research-article
# 40                             Sociology           2000  research-article
# 41                             Sociology           2012  research-article
# 42                             Sociology           1980  research-article
# 43  Management & Organizational Behavior           1995  research-article
# 44                             Sociology           2010  research-article
# 45                             Sociology           2013  research-article
# 46  Management & Organizational Behavior           2004  research-article
# 47  Management & Organizational Behavior           2009  research-article
# 48  Management & Organizational Behavior           2011  research-article
# 49                             Sociology           2007  research-article
# 50                             Sociology           2006  research-article
# 51                             Sociology           2001  research-article
# 52                             Sociology           1980  research-article
# 53  Management & Organizational Behavior           1997  research-article
# 54  Management & Organizational Behavior           1984  research-article
#
#     word_count  year_hand_checked  year_jstor_old year_wos  \
# 0         6943               2010            2010     2010
# 1         8969               2002            2002      NaN
# 2         9074               2007            2007     2007
# 3         6366               1987            1980     1987
# 4        10514               1994            1986     1994
# 5         5131               1985            1985     1985
# 6         5913               2004            2004     2004
# 7         6311               1992            1981     1992
# 8         8670               2011            2011     2011
# 9         7008               2011            2011     2011
# 10        5804               2000            1971     2000
# 11        5643               2007            2007      NaN
# 12        5177               2000            2000     2000
# 13        4771               1977            1977      NaN
# 14        4075               1998            1998     1998
# 15        4147               1985            1985      NaN
# 16       12031               2001            1984     2001
# 17        6070               1994            1994     1994
# 18        2484               2001            2001     2001
# 19        6168               1975            1975      NaN
# 20        6717               2010            2010      NaN
# 21        4835               1989            1989      NaN
# 22        9808               2012            2012      NaN
# 23       11936               2002            1986     2003
# 24        6528               2009            2009     2009
# 25        2490               1994            1987      NaN
# 26        6635               2008            2008     2008
# 27        5395               1998            1998      NaN
# 28       12783               2007            2007     2007
# 29       10791               1996            1986      NaN
# 30        2019               1975            1975      NaN
# 31       15224               1999            1999     1999
# 32        5741               2011            2011      NaN
# 33        4320               2010            2010     2010
# 34       14629               2006            2006     2006
# 35        8762               2009            2009     2009
# 36       10122               1999            1992     1999
# 37        5346               2006            2006     2006
# 38        9383               1996            1994     1996
# 39        5925               2008            2008     2008
# 40        7886               2000            2000      NaN
# 41        8270               2012            2012      NaN
# 42        4946               1986            1980     2020
# 43       10532               2000            1995     2000
# 44        6531               2010            2010      NaN
# 45        7745               2013            2013     2013
# 46        8423               2004            2004      NaN
# 47       11752               2009            2009     2009
# 48        8426               2011            2011     2011
# 49        5513               2007            2007      NaN
# 50        7679               2006            2006     2006
# 51        7340               2003            2001     2003
# 52        2915               1980            1980      NaN
# 53        3795               1997            1997      NaN
# 54        6333               1988            1984     1988
#
#                                      article_name_wos  similarity_wos_title
# 0   Foucault Reads Freud: The Dialogue with Unreas...                 100.0
# 1                                                 NaN                   NaN
# 2   Changes in the practice of eating - A comparat...                  98.0
# 3   COLLECTIVE-BARGAINING AND FACULTY COMPENSATION...                  96.0
# 4   WINDOWS OF OPPORTUNITY - TEMPORAL PATTERNS OF ...                  98.0
# 5   DRAMATURGY AND POLITICAL MYSTIFICATION - POLIT...                  97.0
# 6   Commanding materials: (Re)legitimating authori...                 100.0
# 7   ANONYMITY AND THE RISE OF UNIVERSAL OCCASIONS ...                  99.0
# 8   Constructing Clean Dreams: Accounts, Future Se...                 100.0
# 9   Being Special, Becoming Indigenous: Dilemmas o...                 100.0
# 10          Culture and charisma: Outline of a theory                 100.0
# 11                                                NaN                   NaN
# 12             Consumption caught in the 'cash nexus'                  97.0
# 13                                                NaN                   NaN
# 14      Civil society and agricultural sustainability                 100.0
# 15                                                NaN                   NaN
# 16  "Brainwashing" theories in European parliament...                 100.0
# 17  CONCEPTUALIZING RACISMS - SOCIAL-THEORY, POLIT...                  94.0
# 18  Deepening our commitment, hitting the streets:...                 100.0
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23  How the civil rights movement revitalized labo...                  83.0
# 24  The Production and Transmission of Knowledge i...                 100.0
# 25                                                NaN                   NaN
# 26  Board-Management Relationships: Resources and ...                 100.0
# 27                                                NaN                   NaN
# 28  Health and quality of life of older people, a ...                 100.0
# 29                                                NaN                   NaN
# 30                                                NaN                   NaN
# 31  Race and theory: Culture, poverty, and adaptat...                 100.0
# 32                                                NaN                   NaN
# 33  An analysis of Zimbabwean hotel managers' pers...                  99.0
# 34  Organizational foundings in community context:...                 100.0
# 35  From Experience to Experiential Learning: Cult...                 100.0
# 36  Change and complementarities in the new compet...                 100.0
# 37  Bad apples or bad barrels? A former CEO discus...                 100.0
# 38  Nazism, nationalism, and the sociology of emot...                 100.0
# 39  Sports in civil society: Networks, social capi...                 100.0
# 40                                                NaN                   NaN
# 41                                                NaN                   NaN
# 42  Family Complexity and Children's Behavior Prob...                  40.0
# 43  Linking organizational values to relationships...                 100.0
# 44                                                NaN                   NaN
# 45  Disparities in Academic Achievement: Assessing...                 100.0
# 46                                                NaN                   NaN
# 47  WHEN EXPERIENCE MEETS NATIONAL INSTITUTIONAL E...                  99.0
# 48  Knowledge management and organisational cultur...                 100.0
# 49                                                NaN                   NaN
# 50  Non-profit foundations in four countries of ce...                 100.0
# 51  SHAS as a struggle to create a new field: A Bo...                 100.0
# 52                                                NaN                   NaN
# 53                                                NaN                   NaN
# 54  THE COLLECTIVE STRATEGY FRAMEWORK - AN APPLICA...                  98.0

# %% [markdown]
# **Take-aways:**
#
# - Old and new JSTOR publication year are the same --> Metadata processing may be source of error
# - WOS and hand-checking give same result --> Matched WOS pub year data can be trusted
