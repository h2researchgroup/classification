# %% [markdown]
# ### Inspect most frequent & distinct words for JSTOR articles

# %% [markdown]
# Authors: Nancy Xu, Thomas Lu
#
# Institution: University of California, Berkeley
#
# Date created: March 27, 2022
#
# Date last modified: April 5, 2022

# %% [markdown]
# Code to first preprocess the JSTOR articles, then use ngram to find the most frequentc words, and TFIDF to find the most distinct words for articles labeled positive for each perspective.

# %%
import pickle
import re


import os
import random as rand
from tqdm import tqdm, trange

import numpy as np
import pandas as pd
# from clean_text import stopwords_make, punctstr_make, unicode_make, apache_tokenize, clean_sentence_apache 

import matplotlib.pyplot as plt

import numpy as np
import re
import random
from tqdm import tqdm
from collections import Counter

from collections import Counter

# %% [markdown]
# ## preprocess text data

# %%
def open_test_data(path):
    return open(path, 'rb')
with open_test_data('/home/jovyan/work/tlu_storage/training_cultural_preprocessed_100321.pkl') as f:
    cult = pickle.load(f)

with open_test_data('/home/jovyan/work/tlu_storage/training_demographic_preprocessed_100321.pkl') as f:
    demog = pickle.load(f)

with open_test_data('/home/jovyan/work/tlu_storage/training_orgs_preprocessed_100321.pkl') as f:
    orgs = pickle.load(f)

with open_test_data('/home/jovyan/work/tlu_storage/training_relational_preprocessed_100321.pkl') as f:
    rela = pickle.load(f)

# %%
import itertools
full_text = []

for i in cult['text']:
    joined = list(itertools.chain(*i))
    full_text.append(" ".join(joined))


# ' '.join(cult['text'][0][0])

# %%
full_text_demog = []
for i in demog['text']:
    joined = list(itertools.chain(*i))
    full_text_demog.append(" ".join(joined))

# %%
full_text_orgs = []
for j in orgs['text']:
    joined = list(itertools.chain(*j))
    full_text_orgs.append(" ".join(joined))

# %%
full_text_rela = []
for j in rela['text']:
    joined = list(itertools.chain(*j))
    full_text_rela.append(" ".join(joined))

# %%
cult['full_text'] = full_text
demog['full_text'] = full_text_demog
orgs['full_text'] = full_text_orgs
rela['full_text'] = full_text_rela

# %%
def remove_tags(article):
    article = re.sub('<plain_text> <page sequence="1">', '', article)
    article = re.sub(r'</page>(\<.*?\>)', ' \n ', article)
    # xml tags
    article = re.sub(r'<.*?>', '', article)
    article = re.sub(r'<body.*\n\s*.*\s*.*>', '', article)
    return article

tags_removed = [remove_tags(art) for art in cult['full_text']]
tags_removed_demog = [remove_tags(art) for art in demog['full_text']]
tags_removed_org = [remove_tags(art) for art in orgs['full_text']]
tags_removed_rela = [remove_tags(art) for art in rela['full_text']]
cult['text_no_tags'] = tags_removed
demog['text_no_tags'] = tags_removed_demog
orgs['text_no_tags'] = tags_removed_org
rela['text_no_tags'] = tags_removed_rela

# %%
cult = cult[cult['cultural_score']==1]
demog = demog[demog['demographic_score']==1]
orgs = orgs[orgs['orgs_score']==1]
rela = rela[rela['relational_score']==1]

# %%
cult
# Out:
#                                                   text  cultural_score  \
# 1    [[Civil, Rights, Law, at, Work:, Sex, Discrimi...             1.0
# 3    [[World, Society, and, the, Nation-State, John...             1.0
# 4    [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 5    [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 6    [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 8    [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 17   [[Government, Regulatory, Powers, and, Church,...             1.0
# 23   [[Reexamining, Resistance, as, Oppositional, B...             1.0
# 30   [[Enforcement, is, the, Name, of, the, Game:, ...             1.0
# 32   [[Protest, Group, Success:, The, Impact, of, G...             1.0
# 36   [[The, Microlevel, Discourse, of, Social, Move...             1.0
# 37   [[SMALL, GROUPS, AND, CULTURE, CREATION:, THE,...             1.0
# 44   [[AFTER, MINIMALISM:, TRANSFORMATIONS, OF, STA...             1.0
# 49   [[EMPLOYMENT, RELATIONS, AND, THE, LABOR, MARK...             1.0
# 53   [[ENGENDERING, THE, WORLDS, OF, LABOR:, WOMEN,...             1.0
# 59   [[AMERICAN, SOCIOLOGICAL, ASSOCIATION, Unions,...             1.0
# 62   [[Viewpoints, and, Comments, The, Changing, Fa...             1.0
# 66   [[thnicities, article, The, Author(),, Reprint...             1.0
# 79   [[The, Impact, of, Environmental, Factors, on,...             1.0
# 80   [[Nonconfmity, im, Competitive, Repertoires:, ...             1.0
# 85   [[THE, MARKET, THAT, ANTITRUST, BUILT:, PUBLIC...             1.0
# 89   [[DAVID, .STRONCK, THE, VALUE, SYSTEMS, OF, ST...             1.0
# 94   [[Rules,, Resources,, and, Legitimacy, Process...             1.0
# 101  [[ENTREPRENEURSHIP, IN, THE, MONDRAGON, COOPER...             1.0
# 102  [[Routledge, REVIEW, OF, SOCIAL, ECONOMY,, VOL...             1.0
# 107  [[Conuctability, and, Discordant, Locales:, Re...             1.0
# 108  [[Merchants, of, Law, as, Moral, Entrepreneurs...             1.0
# 109  [[The, Governance, of, Trial, Judges, Herbert,...             1.0
# 112  [[HOW, THE, CIVIL, RIGHTS, MOVEMENT, REVITALIZ...             1.0
# 113  [[Institutional, Isomorphism, and, Informal, S...             1.0
# ..                                                 ...             ...
# 703  [[JOHNSON, Cornell, University, Founding, Team...             1.0
# 704  [[Theor, Soc, DOI, ./sll, Explaining, the, mov...             1.0
# 705  [[Theor, Soc, DOI, For, love, and, money:, Org...             1.0
# 706  [[Institutional, Logics, and, Institutional, P...             1.0
# 707  [[Sociological, Forum,, Vol., No., December, D...             1.0
# 708  [[Organization, Science, Vol., No., March-Apri...             1.0
# 709  [[The, Dynamics, of, Institutionalization:, Tr...             1.0
# 710  [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 711  [[(fifi, JOHNSON, Cornell, University, Logics,...             1.0
# 712  [[Institutional, Logics, and, the, Historical,...             1.0
# 713  [[Justifying, Work:, Occupational, Rhetorics, ...             1.0
# 714  [[The, Myth, Incarnate:, Recoupling, Processes...             1.0
# 715  [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 716  [[<body, xmlns:xlink="http://www..org//xlink"]...             1.0
# 873  [[Theor, Soc, DOI, Before, the, professional, ...             1.0
# 874  [[Organizational, Repertoires, and, Institutio...             1.0
# 875  [[THE, SPREAD, OF, THE, MULTIDIVISIONAL, FORM,...             1.0
# 876  [[Institutionalized, Organizations:, Formal, S...             1.0
# 877  [[The, Social, Construction, of, Organizationa...             1.0
# 878  [[Organizational, Structure, and, the, Institu...             1.0
# 879  [[Institutional, Sources, of, Change, in, the,...             1.0
# 880  [[THE, ROLE, OF, INSTITUTIONALIZATION, IN, CUL...             1.0
# 911  [[Theor, Soc, DOI, Before, the, professional, ...             1.0
# 912  [[Organizational, Repertoires, and, Institutio...             1.0
# 913  [[THE, SPREAD, OF, THE, MULTIDIVISIONAL, FORM,...             1.0
# 914  [[Institutionalized, Organizations:, Formal, S...             1.0
# 915  [[The, Social, Construction, of, Organizationa...             1.0
# 916  [[Organizational, Structure, and, the, Institu...             1.0
# 917  [[Institutional, Sources, of, Change, in, the,...             1.0
# 918  [[THE, ROLE, OF, INSTITUTIONALIZATION, IN, CUL...             1.0
#
#                           primary_subject   edited_filename  \
# 1                               Sociology    10.1086_210317
# 3                               Sociology    10.1086_231174
# 4                               Sociology    10.1086_382347
# 5                               Sociology    10.1086_517899
# 6                               Sociology    10.1086_588742
# 8                               Sociology    10.1086_659639
# 17                              Sociology   10.2307_1385815
# 23                              Sociology   10.2307_1519868
# 30                              Sociology  10.2307_20831088
# 32                              Sociology  10.2307_20831203
# 36                              Sociology  10.2307_20832315
# 37                              Sociology   10.2307_2094525
# 44                              Sociology   10.2307_2096074
# 49                              Sociology   10.2307_2096253
# 53                              Sociology   10.2307_2096420
# 59                              Sociology  10.2307_23019206
# 62                              Sociology  10.2307_23620118
# 66                              Sociology  10.2307_23890858
# 79                              Sociology   10.2307_2580323
# 80                              Sociology   10.2307_2580349
# 85                              Sociology   10.2307_2657540
# 89                              Sociology  10.2307_27521312
# 94                              Sociology   10.2307_2781734
# 101                             Sociology  10.2307_29769232
# 102                             Sociology  10.2307_29770169
# 107                             Sociology   10.2307_3054045
# 108                             Sociology   10.2307_3054053
# 109                             Sociology   10.2307_3054093
# 112                             Sociology   10.2307_3088915
# 113                             Sociology   10.2307_3096861
# ..                                    ...               ...
# 703  Management & Organizational Behavior  10.2307_43548360
# 704                             Sociology  10.2307_41475720
# 705                             Sociology  10.2307_40213580
# 706  Management & Organizational Behavior  10.2307_27856090
# 707                             Sociology  10.2307_20110226
# 708  Management & Organizational Behavior  10.2307_27765981
# 709  Management & Organizational Behavior   10.2307_2393791
# 710                             Sociology    10.1086_522806
# 711  Management & Organizational Behavior  10.2307_43546647
# 712                             Sociology    10.1086_210361
# 713  Management & Organizational Behavior   10.2307_2393987
# 714                             Sociology  10.2307_27801511
# 715                             Sociology    10.1086_603535
# 716                             Sociology    10.1086_367917
# 873                             Sociology   10.2307_4501749
# 874                             Sociology   10.2307_2781235
# 875                             Sociology   10.2307_2095547
# 876                             Sociology   10.2307_2778293
# 877  Management & Organizational Behavior   10.2307_2667051
# 878  Management & Organizational Behavior   10.2307_2392303
# 879  Management & Organizational Behavior   10.2307_2392383
# 880                             Sociology   10.2307_2094862
# 911                             Sociology   10.2307_4501749
# 912                             Sociology   10.2307_2781235
# 913                             Sociology   10.2307_2095547
# 914                             Sociology   10.2307_2778293
# 915  Management & Organizational Behavior   10.2307_2667051
# 916  Management & Organizational Behavior   10.2307_2392303
# 917  Management & Organizational Behavior   10.2307_2392383
# 918                             Sociology   10.2307_2094862
#
#                                           article_name  \
# 1    Civil Rights Law at Work: Sex Discrimination a...
# 3                   World Society and the Nation‐State
# 4    Kinship Networks and Entrepreneurs in China’s ...
# 5    What Is Organizational Imprinting? Cultural En...
# 6    Homeward Bound? Interest, Identity, and Invest...
# 8    The Credit Crisis as a Problem in the Sociolog...
# 17   Government Regulatory Powers and Church Autono...
# 23   Reexamining Resistance as Oppositional Behavio...
# 30   Enforcement is the Name of the Game: An Essay ...
# 32   Protest Group Success: The Impact of Group Cha...
# 36   The Microlevel Discourse of Social Movement Fr...
# 37   Small Groups and Culture Creation: The Idiocul...
# 44   After Minimalism: Transformations of State Bar...
# 49   Employment Relations and the Labor Market: Int...
# 53   Engendering the Worlds of Labor: Women Workers...
# 59   Unions, Norms, and the Rise in U.S. Wage Inequ...
# 62   The Changing Face of Feminism: Dilemmas of the...
# 66   "White Backlash", 'Unfairness' and Justificati...
# 79   The Impact of Environmental Factors on Faction...
# 80   Nonconformity in Competitive Repertoires: A So...
# 85   The Market That Antitrust Built: Public Policy...
# 89   The Value Systems of Students in a Teacher Edu...
# 94   Rules, Resources, and Legitimacy Processes: So...
# 101     ENTREPRENEURSHIP IN THE MONDRAGON COOPERATIVES
# 102  A Socio-instutionalist Critique of the 1990s' ...
# 107  Convictability and Discordant Locales: Reprodu...
# 108  Merchants of Law as Moral Entrepreneurs: Const...
# 109                     The Governance of Trial Judges
# 112  How the Civil Rights Movement Revitalized Labo...
# 113  Institutional Isomorphism and Informal Social ...
# ..                                                 ...
# 703  Founding Teams as Carriers of Competing Logics...
# 704  Explaining the move toward the market in US ac...
# 705  For Love and Money: Organizations' Creative Re...
# 706  Institutional Logics and Institutional Plurali...
# 707  Shareholder Value and the Transformation of th...
# 708  The Multiplicity of Institutional Logics and t...
# 709  The Dynamics of Institutionalization: Transfor...
# 710  The Institutional Logic of Union Organizing an...
# 711  Logics in Action: Managing Institutional Compl...
# 712  Institutional Logics and the Historical Contin...
# 713  Justifying Work: Occupational Rhetorics as Res...
# 714  The Myth Incarnate: Recoupling Processes, Turm...
# 715  Operating Room: Relational Spaces and Microins...
# 716  Institutional Change in Toque Ville: Nouvelle ...
# 873  Before the Professional Project: Success and F...
# 874  Organizational Repertoires and Institutional C...
# 875  The Spread of the Multidivisional Form Among L...
# 876  Institutionalized Organizations: Formal Struct...
# 877  The Social Construction of Organizational Know...
# 878  Organizational Structure and the Institutional...
# 879  Institutional Sources of Change in the Formal ...
# 880  The Role of Institutionalization in Cultural P...
# 911  Before the Professional Project: Success and F...
# 912  Organizational Repertoires and Institutional C...
# 913  The Spread of the Multidivisional Form Among L...
# 914  Institutionalized Organizations: Formal Struct...
# 915  The Social Construction of Organizational Know...
# 916  Organizational Structure and the Institutional...
# 917  Institutional Sources of Change in the Formal ...
# 918  The Role of Institutionalization in Cultural P...
#
#                                              full_text  \
# 1    Civil Rights Law at Work: Sex Discrimination a...
# 3    World Society and the Nation-State John Meyer ...
# 4    <body xmlns:xlink="http://www..org//xlink" xml...
# 5    <body xmlns:xlink="http://www..org//xlink" xml...
# 6    <body xmlns:xlink="http://www..org//xlink" xml...
# 8    <body xmlns:xlink="http://www..org//xlink" xml...
# 17   Government Regulatory Powers and Church Autono...
# 23   Reexamining Resistance as Oppositional Behavio...
# 30   Enforcement is the Name of the Game: An Essay ...
# 32   Protest Group Success: The Impact of Group Cha...
# 36   The Microlevel Discourse of Social Movement Fr...
# 37   SMALL GROUPS AND CULTURE CREATION: THE IDIOCUL...
# 44   AFTER MINIMALISM: TRANSFORMATIONS OF STATE BAR...
# 49   EMPLOYMENT RELATIONS AND THE LABOR MARKET: INT...
# 53   ENGENDERING THE WORLDS OF LABOR: WOMEN WORKERS...
# 59   AMERICAN SOCIOLOGICAL ASSOCIATION Unions, Norm...
# 62   Viewpoints and Comments The Changing Face of F...
# 66   thnicities article The Author(), Reprints and ...
# 79   The Impact of Environmental Factors on Faction...
# 80   Nonconfmity im Competitive Repertoires: Sociol...
# 85   THE MARKET THAT ANTITRUST BUILT: PUBLIC POLICY...
# 89   DAVID .STRONCK THE VALUE SYSTEMS OF STUDENTS I...
# 94   Rules, Resources, and Legitimacy Processes: So...
# 101  ENTREPRENEURSHIP IN THE MONDRAGON COOPERATIVES...
# 102  Routledge REVIEW OF SOCIAL ECONOMY, VOL. LX, N...
# 107  Conuctability and Discordant Locales: Reproduc...
# 108  Merchants of Law as Moral Entrepreneurs: Const...
# 109  The Governance of Trial Judges Herbert Jacob T...
# 112  HOW THE CIVIL RIGHTS MOVEMENT REVITALIZED LABO...
# 113  Institutional Isomorphism and Informal Social ...
# ..                                                 ...
# 703  JOHNSON Cornell University Founding Teams as C...
# 704  Theor Soc DOI ./sll Explaining the move toward...
# 705  Theor Soc DOI For love and money: Organization...
# 706  Institutional Logics and Institutional Plurali...
# 707  Sociological Forum, Vol. No. December DOI: .HH...
# 708  Organization Science Vol. No. March-April issn...
# 709  The Dynamics of Institutionalization: Transfor...
# 710  <body xmlns:xlink="http://www..org//xlink" xml...
# 711  (fifi JOHNSON Cornell University Logics in Act...
# 712  Institutional Logics and the Historical Contin...
# 713  Justifying Work: Occupational Rhetorics as Res...
# 714  The Myth Incarnate: Recoupling Processes, Turm...
# 715  <body xmlns:xlink="http://www..org//xlink" xml...
# 716  <body xmlns:xlink="http://www..org//xlink" xml...
# 873  Theor Soc DOI Before the professional project:...
# 874  Organizational Repertoires and Institutional C...
# 875  THE SPREAD OF THE MULTIDIVISIONAL FORM AMONG L...
# 876  Institutionalized Organizations: Formal Struct...
# 877  The Social Construction of Organizational Know...
# 878  Organizational Structure and the Institutional...
# 879  Institutional Sources of Change in the Formal ...
# 880  THE ROLE OF INSTITUTIONALIZATION IN CULTURAL P...
# 911  Theor Soc DOI Before the professional project:...
# 912  Organizational Repertoires and Institutional C...
# 913  THE SPREAD OF THE MULTIDIVISIONAL FORM AMONG L...
# 914  Institutionalized Organizations: Formal Struct...
# 915  The Social Construction of Organizational Know...
# 916  Organizational Structure and the Institutional...
# 917  Institutional Sources of Change in the Formal ...
# 918  THE ROLE OF INSTITUTIONALIZATION IN CULTURAL P...
#
#                                           text_no_tags
# 1    Civil Rights Law at Work: Sex Discrimination a...
# 3    World Society and the Nation-State John Meyer ...
# 4     Introduction Economists have long concurred t...
# 5     Introduction Organizational sociologists have...
# 6     Introduction Are indigenous investors in Thir...
# 8     Introduction At the heart of the credit crisi...
# 17   Government Regulatory Powers and Church Autono...
# 23   Reexamining Resistance as Oppositional Behavio...
# 30   Enforcement is the Name of the Game: An Essay ...
# 32   Protest Group Success: The Impact of Group Cha...
# 36   The Microlevel Discourse of Social Movement Fr...
# 37   SMALL GROUPS AND CULTURE CREATION: THE IDIOCUL...
# 44   AFTER MINIMALISM: TRANSFORMATIONS OF STATE BAR...
# 49   EMPLOYMENT RELATIONS AND THE LABOR MARKET: INT...
# 53   ENGENDERING THE WORLDS OF LABOR: WOMEN WORKERS...
# 59   AMERICAN SOCIOLOGICAL ASSOCIATION Unions, Norm...
# 62   Viewpoints and Comments The Changing Face of F...
# 66   thnicities article The Author(), Reprints and ...
# 79   The Impact of Environmental Factors on Faction...
# 80   Nonconfmity im Competitive Repertoires: Sociol...
# 85   THE MARKET THAT ANTITRUST BUILT: PUBLIC POLICY...
# 89   DAVID .STRONCK THE VALUE SYSTEMS OF STUDENTS I...
# 94   Rules, Resources, and Legitimacy Processes: So...
# 101  ENTREPRENEURSHIP IN THE MONDRAGON COOPERATIVES...
# 102  Routledge REVIEW OF SOCIAL ECONOMY, VOL. LX, N...
# 107  Conuctability and Discordant Locales: Reproduc...
# 108  Merchants of Law as Moral Entrepreneurs: Const...
# 109  The Governance of Trial Judges Herbert Jacob T...
# 112  HOW THE CIVIL RIGHTS MOVEMENT REVITALIZED LABO...
# 113  Institutional Isomorphism and Informal Social ...
# ..                                                 ...
# 703  JOHNSON Cornell University Founding Teams as C...
# 704  Theor Soc DOI ./sll Explaining the move toward...
# 705  Theor Soc DOI For love and money: Organization...
# 706  Institutional Logics and Institutional Plurali...
# 707  Sociological Forum, Vol. No. December DOI: .HH...
# 708  Organization Science Vol. No. March-April issn...
# 709  The Dynamics of Institutionalization: Transfor...
# 710   Recent events in the labor movement, includin...
# 711  (fifi JOHNSON Cornell University Logics in Act...
# 712  Institutional Logics and the Historical Contin...
# 713  Justifying Work: Occupational Rhetorics as Res...
# 714  The Myth Incarnate: Recoupling Processes, Turm...
# 715   Introduction How is change in institutionaliz...
# 716   Institutions are composed of logics and gover...
# 873  Theor Soc DOI Before the professional project:...
# 874  Organizational Repertoires and Institutional C...
# 875  THE SPREAD OF THE MULTIDIVISIONAL FORM AMONG L...
# 876  Institutionalized Organizations: Formal Struct...
# 877  The Social Construction of Organizational Know...
# 878  Organizational Structure and the Institutional...
# 879  Institutional Sources of Change in the Formal ...
# 880  THE ROLE OF INSTITUTIONALIZATION IN CULTURAL P...
# 911  Theor Soc DOI Before the professional project:...
# 912  Organizational Repertoires and Institutional C...
# 913  THE SPREAD OF THE MULTIDIVISIONAL FORM AMONG L...
# 914  Institutionalized Organizations: Formal Struct...
# 915  The Social Construction of Organizational Know...
# 916  Organizational Structure and the Institutional...
# 917  Institutional Sources of Change in the Formal ...
# 918  THE ROLE OF INSTITUTIONALIZATION IN CULTURAL P...
#
# [234 rows x 7 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['one', 'two', 'three', 'amp', 'may', 'can', 'new', 'also', 'and'])

import string
import re
import nltk

def word_process(tt):
    """
    helper function to lower text, remove stop words, numbers, and empty 
    """
    
    tt = tt.lower()
    
    punc = '''!()-[]{};:'"\, <>./?@#$%^&*_~=\n'''
    # Removing punctuations in string 
    # Using loop + punctuation string 


    for ele in tt:  
        if ele in punc:  
            tt = tt.replace(ele, " ")  

    # read tokens
    tokens = tt.split()
    lst = [token.translate(punc).lower() for token in tokens ]
    
    #remove stop words
    filtered = []
    for i in lst:
        if i not in stop_words:
            filtered.append(i)
    
    # removing singular numbers and singular letters
    pattern = '[0-9]'
    filtered = [re.sub(pattern, '', i) for i in filtered] 
    new = []
    for inp in filtered:
        new.append(' '.join( [w for w in inp.split() if len(w)>1] ))
        
    # filter out empty strings 
    new = [i for i in new if i] 

    dt = [d.split() for d in new]
    
  
    st = ''
    for i in dt:
        st = st + " " + i[0]
    return st
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def get_most_common(df):
    processed = [word_process(i) for i in df['text_no_tags']]
    df['processed'] = processed
    
    cult_words = []
    for k in processed:
        cult_words.extend(k.split())
    
    cult_counts = Counter(cult_words)
    return cult_counts.most_common()

# %%
import pickle

with open('cult_most_common.pkl', 'wb') as f:
    pickle.dump(get_most_common(cult), f)

# %%
import pickle

with open('rela_most_common.pkl', 'wb') as f:
    pickle.dump(get_most_common(rela), f)

# %%
with open('demog_most_common.pkl', 'wb') as f:
    pickle.dump(get_most_common(demog), f)

# %%
with open('orgs_most_common.pkl', 'wb') as f:
    pickle.dump(get_most_common(orgs), f)

# %%
with open('orgs_most_common.pkl', 'rb') as f:
    orgs_most_common = pickle.load(f)

# %%
cult_processed = [word_process(i) for i in cult['text_no_tags']]

# %%
cult['processed'] = cult_processed

# %%
orgs_processed = [word_process(i) for i in orgs['text_no_tags']]
orgs['processed'] = orgs_processed

# %%
demog_processed = [word_process(i) for i in demog['text_no_tags']]
demog['processed'] = demog_processed

# %%
rela_processed = [word_process(i) for i in rela['text_no_tags']]
rela['processed'] = rela_processed

# %%
cult_words = []
for k in cult_processed:
    cult_words.extend(k.split())

# %% [markdown]
# ## Use n grams to inspect the most common words

# %%
from collections import Counter
import numpy as np

# %%
from itertools import tee, islice

def ngrams(lst, n):
  tlst = lst
  while True:
    a, b = tee(tlst)
    l = tuple(islice(a, n))
    if len(l) == n:
      yield l
      next(b)
      tlst = b
    else:
      break

# %%
def most_common_terms(cult_processed, num=30):
    cult_words = []
    for k in cult_processed:
        cult_words.extend(k.split())
    cult_counts = Counter(cult_words)
    top_uni = cult_counts.most_common()[:num]
    cult_counts = Counter(ngrams(cult_words, 2))
    top_bi = cult_counts.most_common()[:num]
    return top_uni, top_bi

# %%
top_uni, top_bi = most_common_terms(demog['processed'][demog.demographic_score == 1.0])
print(top_uni)
# print('\n' + '='*50,'\n')
# print(top_bi)
# Out:
# [('organizational', 11703), ('organizations', 9717), ('women', 7894), ('social', 7299), ('entry', 7053), ('bottom', 5817), ('align', 5733), ('firms', 5697), ('valign', 5685), ('organization', 5656), ('model', 5571), ('change', 5535), ('work', 5512), ('level', 5249), ('firm', 5151), ('effects', 5108), ('job', 4925), ('research', 4799), ('time', 4677), ('group', 4656), ('performance', 4649), ('gender', 4584), ('size', 4377), ('men', 4253), ('management', 4203), ('char', 4162), ('industry', 4040), ('number', 3953), ('data', 3940), ('effect', 3863)]

# %%
top_uni, top_bi = most_common_terms(rela['processed'][rela.relational_score == 1.0])
print(top_uni)
# print('\n' + '='*50,'\n')
# print(top_bi)
# Out:
# [('social', 12351), ('firms', 9929), ('network', 9284), ('ties', 7994), ('organizations', 7628), ('firm', 7608), ('organizational', 6759), ('entry', 6033), ('organization', 5999), ('research', 5925), ('power', 5841), ('market', 5592), ('align', 5283), ('networks', 5210), ('valign', 5163), ('model', 5153), ('bottom', 5053), ('information', 4771), ('data', 4727), ('management', 4646), ('number', 4610), ('industry', 4417), ('work', 4395), ('american', 4341), ('group', 4257), ('time', 4174), ('study', 4171), ('analysis', 4042), ('control', 4032), ('would', 4011)]

# %%
top_uni, top_bi = most_common_terms(cult['processed'][cult.cultural_score == 1.0])
print(top_uni)
# print('\n' + '='*50,'\n')
# print(top_bi)
# Out:
# [('organizational', 9200), ('organizations', 8361), ('social', 7200), ('institutional', 6218), ('organization', 5246), ('management', 4843), ('firms', 4811), ('research', 4115), ('change', 3902), ('time', 3799), ('state', 3796), ('university', 3793), ('american', 3716), ('model', 3523), ('work', 3448), ('press', 3446), ('theory', 3387), ('market', 3271), ('firm', 3216), ('would', 3117), ('entry', 3049), ('analysis', 3004), ('culture', 2947), ('study', 2883), ('journal', 2792), ('science', 2738), ('first', 2721), ('business', 2715), ('data', 2700), ('political', 2688)]

# %% [markdown]
# ## New Distinctive Word Method 1: Summed TF-IDF
# ####  Inspect most distinctive words for positively labeled set for each perspective

# %%
tfidf = TfidfVectorizer(stop_words='english')

   
X = tfidf.fit_transform(corpus)
feature_names = np.array(tfidf.get_feature_names())


# for k in [demog, cult, rela, orgs]:
def get_terms(rela,word_count = 50):
    responses = tfidf.transform(rela['processed'])
    word_inds = np.argsort(np.array(responses.sum(axis=0))[0])[:-word_count+1:-1]
    return [feature_names[i] for i in word_inds]

rela_set = get_terms(rela)
cult_set = get_terms(cult)
demog_set = get_terms(demog)

shared = set(rela_set) & set(cult_set) & set(demog_set)

# %%
[t for t in rela_set if t not in shared]
# Out:
# ['network',
#  'ties',
#  'power',
#  'networks',
#  'board',
#  'job',
#  'information',
#  'control',
#  'capital',
#  'resources',
#  'structure',
#  'status',
#  'business',
#  'economic',
#  'corporate',
#  'relations',
#  'alliance',
#  'exchange',
#  'table',
#  'directors',
#  'members',
#  'knowledge',
#  'results',
#  'groups',
#  'tie',
#  'strategic',
#  'effect',
#  'likely',
#  'ownership',
#  'embeddedness',
#  'resource',
#  'align',
#  'press',
#  'relationships',
#  'state',
#  'structural',
#  'high',
#  'partners',
#  'political',
#  'percent',
#  'contacts',
#  'institutional',
#  'people',
#  'centrality',
#  'dependence',
#  'variable',
#  'hypothesis',
#  'influence']

# %%
[t for t in cult_set if t not in shared]
# Out:
# ['institutional',
#  'culture',
#  'state',
#  'change',
#  'cultural',
#  'press',
#  'legitimacy',
#  'women',
#  'business',
#  'practices',
#  'political',
#  'public',
#  'science',
#  'control',
#  'logics',
#  'education',
#  'adoption',
#  'law',
#  'actors',
#  'structure',
#  'institutions',
#  'diffusion',
#  'process',
#  'york',
#  'environment',
#  'corporate',
#  'movement',
#  'sustainability',
#  'labor',
#  'environmental',
#  'et',
#  'meyer',
#  'review',
#  'different',
#  'al',
#  'field',
#  'economic',
#  'knowledge',
#  'models',
#  'likely',
#  'schools',
#  'government',
#  'legal',
#  'isomorphism',
#  'resources',
#  'institutionalization',
#  'structures',
#  'action']

# %%
[t for t in demog_set if t not in shared]
# Out:
# ['women',
#  'gender',
#  'men',
#  'job',
#  'density',
#  'sex',
#  'female',
#  'change',
#  'size',
#  'jobs',
#  'male',
#  'labor',
#  'diversity',
#  'team',
#  'workers',
#  'population',
#  'hannan',
#  'rates',
#  'age',
#  'groups',
#  'effect',
#  'status',
#  'race',
#  'rate',
#  'black',
#  'founding',
#  'table',
#  'members',
#  'percent',
#  'employment',
#  'white',
#  'align',
#  'differences',
#  'results',
#  'niche',
#  'carroll',
#  'populations',
#  'tenure',
#  'char',
#  'inequality',
#  'managerial',
#  'models',
#  'occupational',
#  'segregation',
#  'competition',
#  'mortality',
#  'variable',
#  'discrimination']
