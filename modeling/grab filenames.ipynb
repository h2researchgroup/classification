# %% [markdown]
# # Compare classification methods for identifying org. science perspectives in JSTOR articles
# ## Using grid search and balanced samples from hand-labeled set of articles
#
# @author: Thomas Lu, Jaren Haber PhD<br>
# @coauthors: Prof. Heather Haveman, UC Berkeley; Yoon Sung Hong, Wayfair<br>
# @contact: Jaren.Haber@georgetown.edu<br>
# @project: Computational Literature Review of Organizational Scholarship<br>
# @date: September 2021
#
# '''
# Trains classifiers to predict whether an article is about a given perspective in org. science. To train the classifiers, uses preliminary labeled articles, broken down as follows:
# Cultural: 105 yes, 209 no
# Relational: 92 yes, 230 no
# Demographic: 77 yes, 249 no
# Compares f1_weighted scores of four model structures using 10-Fold Cross Validation: Logistic regression, SVM, Naive Bayes, and Decision Tree. Oversamples training data to .7 (7:10 minority:majority class).
# '''

# %% [markdown]
# # Initialize

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (3.6.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex in /opt/conda/lib/python3.7/site-packages (from nltk) (2021.8.28)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from nltk) (7.0)

# %%
######################################################
# Import libraries
######################################################

import pandas as pd
import numpy as np
import re
from collections import Counter
from datetime import date
from tqdm import tqdm
import os

import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')

stemmer = WordNetLemmatizer()

from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

import joblib
import csv

from sklearn.datasets import load_files
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression, Perceptron, PassiveAggressiveClassifier, SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split, KFold
# from sklearn.experimental import enable_hist_gradient_boosting

# !pip install imblearn
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline, make_pipeline

import warnings
def warn(*args, **kwargs):
    pass
warnings.warn = warn
warnings.filterwarnings(action='once')

import sys; sys.path.insert(0, "../preprocess/") # For loading functions from files in other directory
from quickpickle import quickpickle_dump, quickpickle_load # custom scripts for quick saving & loading to pickle format
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
######################################################
# Define filepaths
######################################################

data_folder = 'classification'
folder = 'tlu_test'

cwd = os.getcwd()
root = str.replace(cwd, f'{folder}/modeling', '')

thisday = date.today().strftime("%m%d%y")

# Directory for prepared data and trained models: save files here
data_fp = root + f'{data_folder}/data/'
model_fp = root + f'{data_folder}/models/'
logs = root + f'{folder}/modeling/logs/'

# Current article lists
article_list_fp = data_fp + 'filtered_length_index.csv' # Filtered index of research articles
article_paths_fp = data_fp + 'filtered_length_article_paths.csv' # List of article file paths

def get_filepath(name):
    return data_fp + name

# %%
s = 0
for theory in ['cultural', 'demographic', 'relational', 'orgs']:
    df = quickpickle_load(get_filepath(f'training_{theory}_raw_022621.pkl'))
    s += len(df)
s
# Out:
# 3033

# %%
out = pd.read_excel(get_filepath('filtered_length_article_names.xlsx'))
out2 = out[['article_name', 'file_name', 'jstor_url']]
out2
# Out:
#                                             article_name  \
# 0            360-Degree Assessment: Time for Reinvention
# 1                      9/11 Montage: Professors Remember
# 2      A Blended Value Framework for Educating the Ne...
# 3         A Case for Great Books in Management Education
# 4      A Conversation With James G. March on Learning...
# 5      A Conversation with Milton Blood: The New AACS...
# 6      A Cross-Cultural Empirical Analysis of Person-...
# 7      A Meta-Analysis of the Predictive Validity of ...
# 8      A Meta-Analysis on the Effects of Service-Lear...
# 9      A Model of Business School Students' Acceptanc...
# 10     A Model of Management Academics' Intentions to...
# 11     A Paradoxical Leadership Model for Social Entr...
# 12     A Perennial Dilemma in OB Education: Engaging ...
# 13     A Phenomenographic Study of What It Means to S...
# 14     A Retrospective View of Corporate Diversity Tr...
# 15     A Service-Dominant Logic for Management Educat...
# 16     A Service-Learning Kaleidoscope of Insights: C...
# 17     A Suspect MBA Selection Model: The Case agains...
# 18            A Time for Hope: A Response to Nancy Adler
# 19     A Transcendent Business Education for the 21st...
# 20      AACSB Accreditation: Addressing Faculty Concerns
# 21     Academic Advisory Boards' Contributions to Edu...
# 22     Academic Dishonesty in Graduate Business Progr...
# 23     Academic Rankings in Research Institutions: A ...
# 24       Accreditation and the Globalization of Business
# 25     Adaptive Advice in Learning With a Computer-Ba...
# 26     Adding a Web-Based Perspective to the Self-Ass...
# 27     Advising to Avoid or to Cope with Dissertation...
# 28     Aligning or Inflating Your Leadership Self-Ima...
# 29     An Experiential Approach to Cross-Cultural Lea...
# ...                                                  ...
# 65340  The Value of Air Quality Forecasting in the Mi...
# 65341  The Vulnerability of Mobile Home Residents in ...
# 65342                         Tornado Damage Mitigation:
# 65343                     Tornado Vulnerability in Texas
# 65344                        Tornado Warning Trade-Offs:
# 65345  Tornadoes, Social Science, and the False Alarm...
# 65346  Transcending the Adaptation/Mitigation Climate...
# 65347  Understanding the Climate-Sensitive Decisions ...
# 65348                              Unrealized Potential:
# 65349                                    Usable Science?
# 65350  Use of Weather Information for Agricultural De...
# 65351  Using Twentieth-Century U.S. Weather Modificat...
# 65352                  Vermont Climate Change Indicators
# 65353                  Vulnerability beyond Stereotypes:
# 65354  Water, Drought, Climate Change, and Conflict i...
# 65355             ‘‘We Have Seen It with Our Own Eyes’’:
# 65356                   Weather and Individual Happiness
# 65357  Weather, Climate, and Environmental Water Tran...
# 65358  Weather, Climate, and Resource Information Sho...
# 65359                 Weather, Climate, and the Economy:
# 65360                  Weather, Climate, and Worldviews:
# 65361         Weather Forecast Use for Winter Recreation
# 65362   Weather-Index Drought Insurance in Burkina-Faso:
# 65363                                    Weather or Not?
# 65364                             Weather Value at Risk:
# 65365                                  What is the Goal?
# 65366               What Is the True Value of Forecasts?
# 65367  What Stakeholder Needs Tell Us about Enabling ...
# 65368  Why Analyze Mental Models of Local Climate Cha...
# 65369  Wildfire Management and Forecasting Fire Poten...
#
#                               file_name                              jstor_url
# 0      journal-article-10.2307_40214201  https://www.jstor.org/stable/40214201
# 1      journal-article-10.2307_40214096  https://www.jstor.org/stable/40214096
# 2      journal-article-10.2307_23412379                  external-fulltext-any
# 3      journal-article-10.2307_40214312  https://www.jstor.org/stable/40214312
# 4      journal-article-10.2307_41318070                  external-fulltext-any
# 5      journal-article-10.2307_40214313  https://www.jstor.org/stable/40214313
# 6      journal-article-10.2307_40214343  https://www.jstor.org/stable/40214343
# 7      journal-article-10.2307_40214516  https://www.jstor.org/stable/40214516
# 65359  journal-article-10.2307_24907318  https://www.jstor.org/stable/24907318
# 65360  journal-article-10.2307_24907468  https://www.jstor.org/stable/24907468
# 65361  journal-article-10.2307_24907376  https://www.jstor.org/stable/24907376
# 65362  journal-article-10.2307_24906301  https://www.jstor.org/stable/24906301
# 65363  journal-article-10.2307_24907385  https://www.jstor.org/stable/24907385
# 65364  journal-article-10.2307_24907486  https://www.jstor.org/stable/24907486
# 65365  journal-article-10.2307_24907369  https://www.jstor.org/stable/24907369
# 65366  journal-article-10.2307_24906298  https://www.jstor.org/stable/24906298
# 65367  journal-article-10.2307_24907414  https://www.jstor.org/stable/24907414
# 65368  journal-article-10.2307_24907424  https://www.jstor.org/stable/24907424
# 65369  journal-article-10.2307_24907463  https://www.jstor.org/stable/24907463
#
# [65370 rows x 3 columns]

# %%
urls_only = out2[out2['jstor_url'] != 'external-fulltext-any']

# %%
out2.to_csv('filtered_article_file_url.csv', index=False)

# %%
urls_only.to_csv('filtered_article_file_url_existing.csv', index=False)

# %%
# !pwd
# Out:
# /home/jovyan/work/tlu_test/modeling

# %% [markdown]
# ## Load & inspect data

# %%
cult_df = quickpickle_load(cult_labeled_fp)
relt_df = quickpickle_load(relt_labeled_fp)
demog_df = quickpickle_load(demog_labeled_fp)
orgs_df = quickpickle_load(orgs_labeled_fp)

cult_df.head(10)
# Out:
#                                                 text  cultural_score  \
# 0  [[research, note, church_membership, netherlan...             0.0
# 1  [[polish, io_oo, sociological_review, issn, co...             1.0
# 2  [[article, jjdlbsj, grapliy, compassionate, eg...             0.0
# 3  [[reply, allison, more, comparing, regression_...             1.0
# 4  [[determinants, spousal, interaction, marital,...             1.0
# 5  [[wsê, ih, ompany, profile, john, porter, musé...             1.0
# 6  [[andrew_christensen, university_california, l...             1.0
# 7  [[lawyers, consumer_protection, laws, stewart_...             0.0
# 8  [[establishing, sense, personal, control, tran...             1.0
# 9  [[guess, who, coming, town, white_supremacy, e...             0.0
#
#   primary_subject            edited_filename  \
# 0       Sociology             10.1086_210179
# 1       Sociology             10.1086_210317
# 2       Sociology             10.1086_231084
# 3       Sociology             10.1086_231174
# 4       Sociology             10.1086_382347
# 5       Sociology             10.1086_517899
# 6       Sociology             10.1086_588742
# 7       Sociology             10.1086_657524
# 8       Sociology             10.1086_659639
# 9       Sociology  10.1525_irqr.2011.4.3.199
#
#                                         article_name
# 0   Where Do Interorganizational Networks Come From?
# 1  Civil Rights Law at Work: Sex Discrimination a...
# 2  Between Markets and Politics: Organizational R...
# 3                 World Society and the Nation‐State
# 4  Kinship Networks and Entrepreneurs in China’s ...
# 5  What Is Organizational Imprinting? Cultural En...
# 6  Homeward Bound? Interest, Identity, and Invest...
# 7  Corporate Unity in American Trade Policy: A Ne...
# 8  The Credit Crisis as a Problem in the Sociolog...
# 9                    Science, Health, and Nationhood
